# %% [markdown]
# # Rock, Paper, Scissors Classification Model
# - 3 classes/poses: rock, paper, scissors
#   - 1 sample has 5 * 6  features (for now)?
# - Classification neural net
#
# https://colab.research.google.com/github/mrdbourke/pytorch-deep-learning/blob/main/02_pytorch_classification.ipynb#scrollTo=Z2gcR31aHC78

# %% [markdown]
# ## Ablation
#
# https://docs.google.com/spreadsheets/d/1Xy92hWhrxcyvLkxY7Q0RPff1FNVfsLxV0ujrjC6SdFE/edit?gid=427952541#gid=427952541

# %%
from sklearn.metrics._plot.confusion_matrix import confusion_matrix
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import asyncio
import websockets
import json

import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.optim as optim

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_curve, auc, RocCurveDisplay
from sklearn.model_selection import train_test_split, StratifiedGroupKFold, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, LabelBinarizer, MinMaxScaler

# %%
print(torch.__version__)
print(torch._dynamo.__file__)
# Out:
# 2.11.0+cu130
# /home/amiou/Code/Capstone/ECE-SP-26-18-Capstone-Project/venv/lib/python3.14/site-packages/torch/_dynamo/__init__.py

# %%
EPOCHS = 3000
SEED = 40

STD = 0.02
COPY = 5
HIDDEN = 0
DROPOUT = 0.1

LR = 5e-5
WEIGHT_DECAY = 1e-5   # <-- add this line

N_FOLDS = 5

# %%
df = pd.read_csv("data/Glove_v2_norm_wAXYB/output_norm_train.csv")
df = df.drop(columns=["time"], errors='ignore')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 63619 entries, 0 to 63618
# Data columns (total 55 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   BNO0_UnitAccX   63619 non-null  float64
#  1   BNO0_UnitAccY   63619 non-null  float64
#  2   BNO0_UnitAccZ   63619 non-null  float64
#  3   BNO0_RawAccMag  63619 non-null  float64
#  4   BNO0_GyrX       63619 non-null  float64
#  5   BNO0_GyrY       63619 non-null  float64
#  6   BNO0_GyrZ       63619 non-null  float64
#  7   BNO0_MagX       63619 non-null  float64
#  8   BNO0_MagY       63619 non-null  float64
#  9   BNO0_MagZ       63619 non-null  float64
#  10  BNO1_UnitAccX   63619 non-null  float64
#  11  BNO1_UnitAccY   63619 non-null  float64
#  12  BNO1_UnitAccZ   63619 non-null  float64
#  13  BNO1_RawAccMag  63619 non-null  float64
#  14  BNO1_GyrX       63619 non-null  float64
#  15  BNO1_GyrY       63619 non-null  float64
#  16  BNO1_GyrZ       63619 non-null  float64
#  17  BNO1_MagX       63619 non-null  float64
#  18  BNO1_MagY       63619 non-null  float64
#  19  BNO1_MagZ       63619 non-null  float64
#  20  BNO2_UnitAccX   63619 non-null  float64
#  21  BNO2_UnitAccY   63619 non-null  float64
#  22  BNO2_UnitAccZ   63619 non-null  float64
#  23  BNO2_RawAccMag  63619 non-null  float64
#  24  BNO2_GyrX       63619 non-null  float64
#  25  BNO2_GyrY       63619 non-null  float64
#  26  BNO2_GyrZ       63619 non-null  float64
#  27  BNO2_MagX       63619 non-null  float64
#  28  BNO2_MagY       63619 non-null  float64
#  29  BNO2_MagZ       63619 non-null  float64
#  30  BNO3_UnitAccX   63619 non-null  float64
#  31  BNO3_UnitAccY   63619 non-null  float64
#  32  BNO3_UnitAccZ   63619 non-null  float64
#  33  BNO3_RawAccMag  63619 non-null  float64
#  34  BNO3_GyrX       63619 non-null  float64
#  35  BNO3_GyrY       63619 non-null  float64
#  36  BNO3_GyrZ       63619 non-null  float64
#  37  BNO3_MagX       63619 non-null  float64
#  38  BNO3_MagY       63619 non-null  float64
#  39  BNO3_MagZ       63619 non-null  float64
#  40  MPU0_UnitAccX   63619 non-null  float64
#  41  MPU0_UnitAccY   63619 non-null  float64
#  42  MPU0_UnitAccZ   63619 non-null  float64
#  43  MPU0_RawAccMag  63619 non-null  float64
#  44  MPU0_GyrX       63619 non-null  float64
#  45  MPU0_GyrY       63619 non-null  float64
#  46  MPU0_GyrZ       63619 non-null  float64
#  47  MPU1_UnitAccX   63619 non-null  float64
#  48  MPU1_UnitAccY   63619 non-null  float64
#  49  MPU1_UnitAccZ   63619 non-null  float64
#  50  MPU1_RawAccMag  63619 non-null  float64
#  51  MPU1_GyrX       63619 non-null  float64
#  52  MPU1_GyrY       63619 non-null  float64
#  53  MPU1_GyrZ       63619 non-null  float64
#  54  label           63619 non-null  str
# dtypes: float64(54), str(1)
# memory usage: 26.7 MB

# %%
def augment_with_noise(df, label_col="label", noise_fraction=0.05, copies=3, random_state=None):
    if random_state is not None:
        np.random.seed(random_state)
        
    # Isolate only numeric columns, ignoring the label
    features_df = df.drop(columns=[label_col], errors='ignore')
    numeric_cols = features_df.select_dtypes(include=[np.number]).columns
    
    augmented_dfs = [df]  # keep original

    # Calculate the standard deviation for each numeric column
    col_stds = df[numeric_cols].std().values

    for _ in range(copies):
        noisy_df = df.copy()
        
        # Generate noise proportional to each column's standard deviation
        noise = np.random.normal(
            loc=0,
            scale=col_stds * noise_fraction, 
            size=(len(df), len(numeric_cols))
        )
        
        noisy_df[numeric_cols] = noisy_df[numeric_cols] + noise
        augmented_dfs.append(noisy_df)

    return pd.concat(augmented_dfs, ignore_index=True)

# %%
def visualize_gyro_thresholds(df):
    # 1. Identify gyro columns
    gyro_cols = [col for col in df.columns if 'gyr' in col.lower()]
    if not gyro_cols:
        print("No gyroscope columns found!")
        return

    # Flatten all absolute gyro values into one array for distribution analysis
    all_gyro_abs = df[gyro_cols].abs().values.flatten()
    
    # Setup plotting area
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10))

    # --- Plot 1: Time Series (The "Spike" View) ---
    for col in gyro_cols:
        ax1.plot(df[col], alpha=0.5, label=col)
    
    # Add reference lines for potential thresholds
    test_thresholds = [150, 250, 400]
    colors = ['green', 'orange', 'red']
    for t, c in zip(test_thresholds, colors):
        ax1.axhline(t, color=c, linestyle='--', alpha=0.8, label=f'Threshold {t}')
        ax1.axhline(-t, color=c, linestyle='--', alpha=0.8)

    ax1.set_title("Raw Gyroscope Values (All Sensors/Axes)", fontsize=14)
    ax1.set_ylabel("deg/s")
    ax1.legend(bbox_to_anchor=(1.01, 1), loc='upper left', fontsize='small', ncol=2)
    ax1.grid(True, alpha=0.3)

    # --- Plot 2: Histogram (The "Data Loss" View) ---
    # Use log scale for Y so we can see the rare outliers/spikes easily
    ax2.hist(all_gyro_abs, bins=100, color='skyblue', edgecolor='black', alpha=0.7, log=True)
    
    for t, c in zip(test_thresholds, colors):
        # Calculate how much data is KEPT at this threshold
        percent_kept = (all_gyro_abs <= t).mean() * 100
        ax2.axvline(t, color=c, linestyle='--', linewidth=2)
        ax2.text(t+5, ax2.get_ylim()[1]*0.5, f"Keep {percent_kept:.1f}%", color=c, fontweight='bold')

    ax2.set_title("Distribution of Absolute Gyro Values (Log Scale)", fontsize=14)
    ax2.set_xlabel("Absolute Value |deg/s|")
    ax2.set_ylabel("Frequency (Log Scale)")
    ax2.grid(True, alpha=0.2)

    plt.tight_layout()
    plt.show()

    # Print a quick summary table
    print("\n--- Data Retention Summary ---")
    for t in [100, 150, 200, 250, 300, 400, 500]:
        percent = (all_gyro_abs <= t).mean() * 100
        print(f"Threshold {t:3}: Keeps {percent:6.2f}% of samples")

# Assuming 'df' is your loaded DataFrame
visualize_gyro_thresholds(df)
# Out:
# --- Data Retention Summary ---
# Threshold 100: Keeps  97.73% of samples
# Threshold 150: Keeps  98.79% of samples
# Threshold 200: Keeps  99.32% of samples
# Threshold 250: Keeps  99.60% of samples
# Threshold 300: Keeps  99.74% of samples
# Threshold 400: Keeps  99.88% of samples
# Threshold 500: Keeps  99.93% of samples

# %%
# df = df[df['label'] != "none"]

# %%
def filter_gyro_spikes(df, threshold=250.0):
    """
    Removes rows where any gyroscope value (absolute) exceeds the threshold.
    """
    # Identify all columns that contain gyroscope data
    gyro_cols = [col for col in df.columns if 'gyr' in col.lower()]
    
    # Create a mask where True means the row is "clean"
    # (All gyro values in that row are <= threshold)
    clean_mask = (df[gyro_cols].abs() <= threshold).all(axis=1)
    
    df_filtered = df[clean_mask].copy()
    
    rows_removed = len(df) - len(df_filtered)
    print(f"Filtered {rows_removed} rows containing gyro spikes > {threshold}")
    
    return df_filtered

def drop_gyro_columns(df):
    """
    Removes all columns related to gyroscope readings.
    """
    gyro_cols = [col for col in df.columns if 'gyr' in col.lower()]
    df_dropped = df.drop(columns=gyro_cols)
    
    print(f"Dropped {len(gyro_cols)} gyroscope columns.")
    return df_dropped

# %%
import pandas as pd

def get_window_data(df, window_size):
    # 1. Separate features and label
    features_df = df.drop(columns=['label']).copy()
    
    # 2. Numeric conversion for features
    features_df = features_df.apply(pd.to_numeric, errors='coerce').fillna(0)

    # 3. Calculate Rolling Mean and Variance
    rolling_mean = features_df.rolling(window=window_size).mean()
    rolling_var = features_df.rolling(window=window_size).var()
    
    rolling_mean.columns = [f"{name}_mean" for name in features_df.columns]
    rolling_var.columns = [f"{name}_var" for name in features_df.columns]

    combined_df = pd.concat([rolling_mean, rolling_var], axis=1)

    # 4. HANDLE LABELS: Map to integers first
    # Create a mapping (e.g., 'none': 0, 'paper': 1, etc.)
    unique_labels = df['label'].unique()
    label_to_id = {label: i for i, label in enumerate(unique_labels)}
    id_to_label = {i: label for label, i in label_to_id.items()}
    
    temp_label_ids = df['label'].map(label_to_id)

    # 5. Calculate Mode on the integer IDs
    # Now that it's numeric, rolling().apply() will work!
    combined_df['label'] = (
        temp_label_ids
        .rolling(window=window_size)
        .apply(lambda x: pd.Series(x).mode()[0], raw=False)
    )

    # 6. Map back to strings
    combined_df['label'] = combined_df['label'].map(id_to_label)

    # 7. Drop NaNs and reset
    return combined_df.dropna().reset_index(drop=True)

# %%
# 1. Clean the data based on movement intensity
df = filter_gyro_spikes(df, threshold=150.0)

# 2. Strip the gyro features if you want a purely static-pose model
df = drop_gyro_columns(df)
# Out:
# Filtered 2969 rows containing gyro spikes > 150.0
# Dropped 18 gyroscope columns.

# %%
df.head(5)
# Out:
#    BNO0_UnitAccX  BNO0_UnitAccY  BNO0_UnitAccZ  BNO0_RawAccMag  BNO0_MagX  \
# 0          0.033         -0.623         -0.781         2165.11      0.095
# 1          0.036         -0.615         -0.788         2546.68      0.113
# 2         -0.249         -0.343         -0.906         2704.27      0.527
# 3         -0.336         -0.282         -0.899         2416.70      0.538
# 4         -0.307         -0.208         -0.929         2615.39      0.542
#
#    BNO0_MagY  BNO0_MagZ  BNO1_UnitAccX  BNO1_UnitAccY  BNO1_UnitAccZ  ...  \
# 0      0.265      0.959          0.791         -0.022         -0.612  ...
# 1      0.259      0.959          0.791         -0.022         -0.612  ...
# 2      0.008      0.850          0.230          0.071         -0.971  ...
# 3      0.000      0.843          0.198          0.071         -0.978  ...
# 4     -0.029      0.840          0.170          0.134         -0.976  ...
#
#    BNO3_MagZ  MPU0_UnitAccX  MPU0_UnitAccY  MPU0_UnitAccZ  MPU0_RawAccMag  \
# 0      0.909          0.588          0.048          0.807          11.171
# 1      0.713          0.636          0.022          0.772          10.799
# 2      0.728          0.623          0.027          0.782          10.903
# 3      0.730          0.636          0.011          0.771          11.005
# 4      0.708          0.684         -0.040          0.729          10.249
#
#    MPU1_UnitAccX  MPU1_UnitAccY  MPU1_UnitAccZ  MPU1_RawAccMag  label
# 0          0.595         -0.307          0.743          10.340   none
# 1          0.616         -0.326          0.717          10.254   none
# 2          0.616         -0.352          0.704           9.768   none
# 3          0.658         -0.343          0.670          10.591   none
# 4          0.645         -0.401          0.651           9.689   none
#
# [5 rows x 37 columns]

# %%
#df = get_window_data(df, 5)

# %%
# 1. Split FIRST to prevent data leakage. 
# stratify=df['label'] ensures the 1000 test rows have the correct class proportions.
df_train, testing = train_test_split(df, test_size=1000, stratify=df['label'], random_state=42)

# Reset indices for cleanliness
df_train = df_train.reset_index(drop=True)
testing = testing.reset_index(drop=True)

# 2. Balance the TRAINING data only
min_count = df_train['label'].value_counts().min()
df_balanced = df_train.groupby('label').sample(n=min_count, random_state=42).reset_index(drop=True)

print("Balanced Training Class Counts:")
print(df_balanced['label'].value_counts())

# Now 'df_balanced' is ready for your augment_with_noise() function!
df = df_balanced
# Out:
# Balanced Training Class Counts:
# label
# A           742
# B           742
# X           742
# Y           742
# none        742
# paper       742
# rock        742
# scissors    742
# Name: count, dtype: int64

# %%
# Print original size with context
print(f"Original row count: {len(df)}")

augmented_df = augment_with_noise(
    df,
    label_col="label",
    noise_fraction=0.0005, # Using the updated parameter from the previous cell
    copies=COPY,
    random_state=42      # Using the new reproducibility parameter
)

print(f"Augmented row count: {len(augmented_df)}")

# If you must overwrite df to save memory, do it at the very end
df = augmented_df
# Out:
# Original row count: 5936
# Augmented row count: 35616

# %%
df.head()
# Out:
#    BNO0_UnitAccX  BNO0_UnitAccY  BNO0_UnitAccZ  BNO0_RawAccMag  BNO0_MagX  \
# 0          0.684          0.521         -0.510         2431.76     -0.894
# 1          0.454          0.064         -0.889         2620.86     -0.650
# 2          0.672          0.518         -0.530         2506.18     -0.878
# 3          0.748         -0.211         -0.629         2640.04     -0.924
# 4          0.716          0.102         -0.691         2333.26     -0.911
#
#    BNO0_MagY  BNO0_MagZ  BNO1_UnitAccX  BNO1_UnitAccY  BNO1_UnitAccZ  ...  \
# 0     -0.406      0.189          0.895          0.394         -0.210  ...
# 1     -0.004      0.760          0.795          0.371         -0.479  ...
# 2     -0.408      0.250          0.891          0.398         -0.217  ...
# 3      0.133      0.357          0.958         -0.242         -0.154  ...
# 4      0.095      0.400          0.977         -0.010         -0.214  ...
#
#    BNO3_MagZ  MPU0_UnitAccX  MPU0_UnitAccY  MPU0_UnitAccZ  MPU0_RawAccMag  \
# 0      0.949          0.839          0.269          0.474          10.653
# 1      0.734          0.695         -0.083          0.715          10.965
# 2      0.947          0.846          0.253          0.470          10.815
# 3      0.919          0.440          0.129          0.889          11.681
# 4      0.923          0.552          0.100          0.828          10.411
#
#    MPU1_UnitAccX  MPU1_UnitAccY  MPU1_UnitAccZ  MPU1_RawAccMag  label
# 0          0.772          0.634          0.044          10.554      A
# 1          0.829          0.298          0.474          10.108      A
# 2          0.788          0.614          0.044          10.665      A
# 3          0.504          0.600          0.621          10.617      A
# 4          0.595          0.596          0.539           9.999      A
#
# [5 rows x 37 columns]

# %%
df_train  = df
df_train.label.value_counts()
# Out:
# label
# A           4452
# B           4452
# X           4452
# Y           4452
# none        4452
# paper       4452
# rock        4452
# scissors    4452
# Name: count, dtype: int64

# %% [markdown]
# ## Make data and label dfs

# %%
# Scramble the rows
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)
# df_all = df_all.drop(columns=["time"])
df_train.head(3)
# Out:
#    BNO0_UnitAccX  BNO0_UnitAccY  BNO0_UnitAccZ  BNO0_RawAccMag  BNO0_MagX  \
# 0       0.796921       0.542167       0.265868     2458.124868  -0.747368
# 1       0.188000       0.350000      -0.918000     2510.560000  -0.561000
# 2       0.679031       0.519031      -0.520061     2462.570715  -0.896962
#
#    BNO0_MagY  BNO0_MagZ  BNO1_UnitAccX  BNO1_UnitAccY  BNO1_UnitAccZ  ...  \
# 0  -0.229208  -0.623916       0.915029       0.390113       0.100753  ...
# 1  -0.348000   0.751000      -0.145000      -0.190000      -0.971000  ...
# 2  -0.411089   0.160912       0.890868       0.399544      -0.213074  ...
#
#    BNO3_MagZ  MPU0_UnitAccX  MPU0_UnitAccY  MPU0_UnitAccZ  MPU0_RawAccMag  \
# 0   0.968871       0.486895       0.817419      -0.310052        9.832474
# 1   0.925000       0.866000      -0.226000       0.447000       10.459000
# 2   0.948622       0.845696       0.258455       0.470180       10.462179
#
#    MPU1_UnitAccX  MPU1_UnitAccY  MPU1_UnitAccZ  MPU1_RawAccMag  label
# 0       0.179368       0.768628      -0.614554       10.481181   none
# 1       0.856000       0.500000       0.130000       10.435000      X
# 2       0.783623       0.620730       0.029617       10.401189      A
#
# [3 rows x 37 columns]

# %%
# Select only columns that contain text (strings or objects)
text_cols = df_train.select_dtypes(include=['object', 'string']).columns

# Strip leading and trailing whitespace from those columns
df_train[text_cols] = df_train[text_cols].apply(lambda x: x.str.strip())

# %%
# 1. Get all unique labels and sort them alphabetically to guarantee consistency
unique_labels = sorted(df_train["label"].unique())

# 2. Dynamically generate the dictionary using enumerate
mapping = {label: idx for idx, label in enumerate(unique_labels)}

# Print the mapping so you know exactly what the model is learning!
print(f"Dynamic mapping generated: {mapping}")

y_train = df_train["label"].map(mapping)

# 2. Safety check: Ensure no labels were misspelled and turned into NaNs
if y_train.isna().any():
    print("WARNING: Some labels were not in the mapping dictionary and became NaN!")
    print(df_train[y_train.isna()]['label'].unique()) # Show the problem labels

# 3. Separate the features (X) from the labels (y)
X_train = df_train.drop(columns=["label"])
# Out:
# Dynamic mapping generated: {'A': 0, 'B': 1, 'X': 2, 'Y': 3, 'none': 4, 'paper': 5, 'rock': 6, 'scissors': 7}

# %%
# torch.tensor() creates a clean copy, removing the read-only warning
# .to_numpy() is the modern pandas standard
X = torch.tensor(X_train.to_numpy()).type(torch.float)
y = torch.tensor(y_train.to_numpy()).type(torch.long)

# Split data into train and validation sets
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X,
    y,
    test_size=0.2, 
    stratify=y,       
    random_state=42
)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Move to device
X_train_final = X_train_final.to(device)
y_train_final = y_train_final.to(device)
X_val = X_val.to(device)
y_val = y_val.to(device)

# --- ADD THIS SECTION ---
from torch.utils.data import TensorDataset, DataLoader
BATCH_SIZE = 1024
train_dataset = TensorDataset(X_train_final, y_train_final)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
X_val_tensor = X_val
y_val_tensor = y_val
# -----------------------
print(f"Training rows: {len(X_train_final)}, Validation rows: {len(X_val)}")

# Make device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda
# Training rows: 28492, Validation rows: 7124
# Using device: cuda

# %%
y
# Out:
# tensor([4, 2, 0,  ..., 7, 1, 5])

# %% [markdown]
# # Model Training

# %%
# Dynamically get input features from your PyTorch training tensor
input_features = X_train_final.shape[1]

# Dynamically count the number of unique classes from your label tensor
classes = len(torch.unique(y_train_final))

# Set hidden units (assuming HIDDEN is defined earlier)
hidden_units = HIDDEN

# Clearly print the architecture parameters
print(f"Input features: {input_features}")
print(f"Output classes: {classes}")
print(f"Hidden units: {hidden_units}")
# Out:
# Input features: 36
# Output classes: 8
# Hidden units: 0

# %%
# MODEL 4
class RPSModel(nn.Module):
    def __init__(self, input_features, output_features):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_features, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(32, output_features)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Create an instance of the model and send it to target device
model_4 = RPSModel(
    input_features=input_features, 
    output_features=classes
).to(device)

# Create a loss function
loss_fn = nn.CrossEntropyLoss()

# Create an optimizer with weight decay
optimizer = optim.AdamW(params=model_4.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=15
)

# Calculate accuracy with a device-safety check
def accuracy_fn(y_true, y_pred):
    # Ensure both tensors are on the same device before comparing
    if y_true.device != y_pred.device:
        y_pred = y_pred.to(y_true.device)
        
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %% [markdown]
# #Training

# %%
# Set the seed if you want the exact same "random" number every time
random.seed(42) 

random_integer = random.randint(1, 100)
print(f"Random integer: {random_integer}")
# Out:
# Random integer: 82

# %% [markdown]
# # Training Loop

# %%
previous_lr = LR
train_losses = []
val_losses = []
for epoch in range(EPOCHS):
    ### Training Phase
    model_4.train()
    total_train_loss, total_train_acc = 0, 0
    
    for batch_X, batch_y in train_dataloader:
        y_logits = model_4(batch_X) 
        y_pred = torch.argmax(y_logits, dim=1)
        
        loss = loss_fn(y_logits, batch_y)
        acc = accuracy_fn(y_true=batch_y, y_pred=y_pred) 
        
        optimizer.zero_grad()
        loss.backward()
        
        # Optional gradient clipping (add this line)
        torch.nn.utils.clip_grad_norm_(model_4.parameters(), max_norm=1.0)
        
        optimizer.step()
        
        total_train_loss += loss.item()
        total_train_acc += acc
        
    avg_train_loss = total_train_loss / len(train_dataloader)
    avg_train_acc = total_train_acc / len(train_dataloader)

    ### Evaluation Phase
    model_4.eval()
    with torch.inference_mode():
        val_logits = model_4(X_val_tensor)
        val_pred = torch.argmax(val_logits, dim=1)
        
        val_loss = loss_fn(val_logits, y_val_tensor)
        val_acc = accuracy_fn(y_true=y_val_tensor, y_pred=val_pred)

    # Record losses
    train_losses.append(avg_train_loss)
    val_losses.append(val_loss.item())

    # 🔁 Step the scheduler based on validation loss
    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != previous_lr:
        print(f"Learning rate reduced to {current_lr:.2e}")
        previous_lr = current_lr

    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Train Loss: {avg_train_loss:.5f}, Train Acc: {avg_train_acc:.2f}% | Val loss: {val_loss:.5f}, Val acc: {val_acc:.2f}%")
# Out:
# Epoch: 0 | Train Loss: 2.16474, Train Acc: 12.14% | Val loss: 2.12885, Val acc: 13.11%
# Epoch: 10 | Train Loss: 1.96679, Train Acc: 25.94% | Val loss: 1.91090, Val acc: 32.14%
# Epoch: 20 | Train Loss: 1.85611, Train Acc: 29.66% | Val loss: 1.80113, Val acc: 34.91%
# Epoch: 30 | Train Loss: 1.76627, Train Acc: 32.11% | Val loss: 1.69962, Val acc: 37.93%
# Epoch: 40 | Train Loss: 1.66819, Train Acc: 35.43% | Val loss: 1.61799, Val acc: 40.97%
# Epoch: 50 | Train Loss: 1.57508, Train Acc: 38.80% | Val loss: 1.53601, Val acc: 41.02%
# Epoch: 60 | Train Loss: 1.48692, Train Acc: 42.63% | Val loss: 1.41213, Val acc: 50.10%
# Epoch: 70 | Train Loss: 1.41102, Train Acc: 46.31% | Val loss: 1.30833, Val acc: 55.98%
# Epoch: 80 | Train Loss: 1.34705, Train Acc: 49.03% | Val loss: 1.22161, Val acc: 61.68%
# Epoch: 90 | Train Loss: 1.29860, Train Acc: 51.32% | Val loss: 1.17260, Val acc: 60.35%
# Epoch: 100 | Train Loss: 1.24287, Train Acc: 53.76% | Val loss: 1.20024, Val acc: 57.16%
# Epoch: 110 | Train Loss: 1.19536, Train Acc: 56.42% | Val loss: 1.03088, Val acc: 70.69%
# Epoch: 120 | Train Loss: 1.15172, Train Acc: 57.73% | Val loss: 0.98326, Val acc: 70.33%
# Epoch: 130 | Train Loss: 1.10826, Train Acc: 59.58% | Val loss: 0.96446, Val acc: 71.11%
# Epoch: 140 | Train Loss: 1.06882, Train Acc: 61.41% | Val loss: 0.97094, Val acc: 68.02%
# Epoch: 150 | Train Loss: 1.03447, Train Acc: 62.70% | Val loss: 0.90598, Val acc: 72.11%
# Learning rate reduced to 2.50e-05
# Epoch: 160 | Train Loss: 1.00880, Train Acc: 63.66% | Val loss: 0.84893, Val acc: 73.41%
# Epoch: 170 | Train Loss: 0.99321, Train Acc: 64.09% | Val loss: 0.81001, Val acc: 75.35%
# Epoch: 180 | Train Loss: 0.97749, Train Acc: 64.84% | Val loss: 0.78908, Val acc: 75.80%
# Epoch: 190 | Train Loss: 0.95378, Train Acc: 65.84% | Val loss: 0.78251, Val acc: 75.83%
# Epoch: 200 | Train Loss: 0.93730, Train Acc: 66.63% | Val loss: 0.75951, Val acc: 77.20%
# Epoch: 210 | Train Loss: 0.91516, Train Acc: 67.84% | Val loss: 0.70688, Val acc: 77.67%
# Epoch: 220 | Train Loss: 0.88797, Train Acc: 69.18% | Val loss: 0.71817, Val acc: 80.52%
# Epoch: 230 | Train Loss: 0.87419, Train Acc: 69.84% | Val loss: 0.67164, Val acc: 79.20%
# Epoch: 240 | Train Loss: 0.84771, Train Acc: 70.95% | Val loss: 0.66087, Val acc: 82.75%
# Epoch: 250 | Train Loss: 0.82410, Train Acc: 71.84% | Val loss: 0.65720, Val acc: 81.93%
# Epoch: 260 | Train Loss: 0.80607, Train Acc: 72.73% | Val loss: 0.66731, Val acc: 79.87%
# Epoch: 270 | Train Loss: 0.78118, Train Acc: 73.62% | Val loss: 0.63105, Val acc: 81.51%
# Epoch: 280 | Train Loss: 0.76566, Train Acc: 74.30% | Val loss: 0.55303, Val acc: 84.98%
# Epoch: 290 | Train Loss: 0.74780, Train Acc: 74.98% | Val loss: 0.59621, Val acc: 83.59%
# Epoch: 300 | Train Loss: 0.72306, Train Acc: 76.16% | Val loss: 0.57529, Val acc: 84.04%
# Epoch: 310 | Train Loss: 0.70359, Train Acc: 76.57% | Val loss: 0.48448, Val acc: 86.37%
# Epoch: 320 | Train Loss: 0.69110, Train Acc: 77.29% | Val loss: 0.52269, Val acc: 86.69%
# Epoch: 330 | Train Loss: 0.67558, Train Acc: 77.77% | Val loss: 0.54049, Val acc: 83.21%
# Epoch: 340 | Train Loss: 0.64794, Train Acc: 78.82% | Val loss: 0.45543, Val acc: 88.32%
# Epoch: 350 | Train Loss: 0.63452, Train Acc: 79.48% | Val loss: 0.42411, Val acc: 90.08%
# Epoch: 360 | Train Loss: 0.61763, Train Acc: 80.13% | Val loss: 0.47635, Val acc: 86.65%
# Epoch: 370 | Train Loss: 0.60023, Train Acc: 80.80% | Val loss: 0.44010, Val acc: 88.39%
# Epoch: 380 | Train Loss: 0.58298, Train Acc: 81.53% | Val loss: 0.41379, Val acc: 88.00%
# Epoch: 390 | Train Loss: 0.56946, Train Acc: 82.04% | Val loss: 0.40846, Val acc: 89.01%
# Epoch: 400 | Train Loss: 0.54584, Train Acc: 83.02% | Val loss: 0.38875, Val acc: 91.16%
# Learning rate reduced to 1.25e-05
# Epoch: 410 | Train Loss: 0.53192, Train Acc: 83.39% | Val loss: 0.31408, Val acc: 93.23%
# Epoch: 420 | Train Loss: 0.53002, Train Acc: 83.60% | Val loss: 0.32155, Val acc: 91.68%
# Epoch: 430 | Train Loss: 0.51958, Train Acc: 83.99% | Val loss: 0.31317, Val acc: 92.27%
# Epoch: 440 | Train Loss: 0.51359, Train Acc: 83.80% | Val loss: 0.30827, Val acc: 91.25%
# Epoch: 450 | Train Loss: 0.50146, Train Acc: 84.53% | Val loss: 0.27965, Val acc: 94.37%
# Epoch: 460 | Train Loss: 0.50012, Train Acc: 84.45% | Val loss: 0.28881, Val acc: 91.73%
# Learning rate reduced to 6.25e-06
# Epoch: 470 | Train Loss: 0.49797, Train Acc: 84.67% | Val loss: 0.26991, Val acc: 93.73%
# Epoch: 480 | Train Loss: 0.48697, Train Acc: 84.97% | Val loss: 0.27079, Val acc: 93.29%
# Epoch: 490 | Train Loss: 0.48854, Train Acc: 84.95% | Val loss: 0.26918, Val acc: 93.68%
# Epoch: 500 | Train Loss: 0.48382, Train Acc: 85.13% | Val loss: 0.26635, Val acc: 93.16%
# Epoch: 510 | Train Loss: 0.48088, Train Acc: 85.07% | Val loss: 0.26550, Val acc: 93.91%
# Epoch: 520 | Train Loss: 0.47436, Train Acc: 85.29% | Val loss: 0.25979, Val acc: 94.02%
# Epoch: 530 | Train Loss: 0.47060, Train Acc: 85.67% | Val loss: 0.25104, Val acc: 94.39%
# Epoch: 540 | Train Loss: 0.47128, Train Acc: 85.56% | Val loss: 0.25478, Val acc: 93.85%
# Epoch: 550 | Train Loss: 0.46228, Train Acc: 85.97% | Val loss: 0.25923, Val acc: 93.57%
# Epoch: 560 | Train Loss: 0.46328, Train Acc: 85.94% | Val loss: 0.23766, Val acc: 94.57%
# Epoch: 570 | Train Loss: 0.45407, Train Acc: 86.19% | Val loss: 0.24679, Val acc: 93.88%
# Epoch: 580 | Train Loss: 0.45758, Train Acc: 85.86% | Val loss: 0.24602, Val acc: 93.59%
# Learning rate reduced to 3.13e-06
# Epoch: 590 | Train Loss: 0.45899, Train Acc: 86.01% | Val loss: 0.23817, Val acc: 94.24%
# Epoch: 600 | Train Loss: 0.45230, Train Acc: 86.19% | Val loss: 0.23163, Val acc: 94.69%
# Epoch: 610 | Train Loss: 0.45274, Train Acc: 86.04% | Val loss: 0.22995, Val acc: 94.55%
# Epoch: 620 | Train Loss: 0.45292, Train Acc: 86.23% | Val loss: 0.23241, Val acc: 94.12%
# Learning rate reduced to 1.56e-06
# Epoch: 630 | Train Loss: 0.44720, Train Acc: 86.47% | Val loss: 0.22780, Val acc: 94.62%
# Epoch: 640 | Train Loss: 0.44558, Train Acc: 86.47% | Val loss: 0.22788, Val acc: 94.57%
# Epoch: 650 | Train Loss: 0.44680, Train Acc: 86.26% | Val loss: 0.22945, Val acc: 94.55%
# Epoch: 660 | Train Loss: 0.45432, Train Acc: 86.07% | Val loss: 0.22623, Val acc: 94.76%
# Epoch: 670 | Train Loss: 0.44464, Train Acc: 86.22% | Val loss: 0.22512, Val acc: 94.51%
# Epoch: 680 | Train Loss: 0.44300, Train Acc: 86.37% | Val loss: 0.22582, Val acc: 94.54%
# Learning rate reduced to 7.81e-07
# Epoch: 690 | Train Loss: 0.44205, Train Acc: 86.49% | Val loss: 0.22431, Val acc: 94.46%
# Learning rate reduced to 3.91e-07
# Epoch: 700 | Train Loss: 0.44444, Train Acc: 86.47% | Val loss: 0.22438, Val acc: 94.55%
# Epoch: 710 | Train Loss: 0.44607, Train Acc: 86.42% | Val loss: 0.22445, Val acc: 94.44%
# Epoch: 720 | Train Loss: 0.44376, Train Acc: 86.28% | Val loss: 0.22470, Val acc: 94.48%
# Learning rate reduced to 1.95e-07
# Epoch: 730 | Train Loss: 0.44986, Train Acc: 86.08% | Val loss: 0.22289, Val acc: 94.58%
# Epoch: 740 | Train Loss: 0.44376, Train Acc: 86.55% | Val loss: 0.22386, Val acc: 94.58%
# Learning rate reduced to 9.77e-08
# Epoch: 750 | Train Loss: 0.44236, Train Acc: 86.55% | Val loss: 0.22432, Val acc: 94.58%
# Learning rate reduced to 4.88e-08
# Epoch: 760 | Train Loss: 0.44445, Train Acc: 86.57% | Val loss: 0.22208, Val acc: 94.53%
# Epoch: 770 | Train Loss: 0.44216, Train Acc: 86.30% | Val loss: 0.22308, Val acc: 94.53%
# Learning rate reduced to 2.44e-08
# Epoch: 780 | Train Loss: 0.44238, Train Acc: 86.50% | Val loss: 0.22375, Val acc: 94.55%
# Epoch: 790 | Train Loss: 0.44634, Train Acc: 86.26% | Val loss: 0.22317, Val acc: 94.54%
# Learning rate reduced to 1.22e-08
# Epoch: 800 | Train Loss: 0.44347, Train Acc: 86.49% | Val loss: 0.22348, Val acc: 94.55%
# Epoch: 810 | Train Loss: 0.43730, Train Acc: 86.74% | Val loss: 0.22339, Val acc: 94.53%
# Epoch: 820 | Train Loss: 0.44696, Train Acc: 86.14% | Val loss: 0.22372, Val acc: 94.50%
# Epoch: 830 | Train Loss: 0.44645, Train Acc: 86.46% | Val loss: 0.22279, Val acc: 94.62%
# Epoch: 840 | Train Loss: 0.44262, Train Acc: 86.44% | Val loss: 0.22312, Val acc: 94.53%
# Epoch: 850 | Train Loss: 0.44584, Train Acc: 86.42% | Val loss: 0.22297, Val acc: 94.57%
# Epoch: 860 | Train Loss: 0.44090, Train Acc: 86.53% | Val loss: 0.22307, Val acc: 94.57%
# Epoch: 870 | Train Loss: 0.44052, Train Acc: 86.52% | Val loss: 0.22290, Val acc: 94.51%
# Epoch: 880 | Train Loss: 0.44665, Train Acc: 86.37% | Val loss: 0.22319, Val acc: 94.48%
# Epoch: 890 | Train Loss: 0.44352, Train Acc: 86.32% | Val loss: 0.22333, Val acc: 94.51%
# Epoch: 900 | Train Loss: 0.44572, Train Acc: 86.32% | Val loss: 0.22220, Val acc: 94.57%
# Epoch: 910 | Train Loss: 0.44629, Train Acc: 86.24% | Val loss: 0.22334, Val acc: 94.55%
# Epoch: 920 | Train Loss: 0.44568, Train Acc: 86.44% | Val loss: 0.22297, Val acc: 94.55%
# Epoch: 930 | Train Loss: 0.44488, Train Acc: 86.58% | Val loss: 0.22324, Val acc: 94.50%
# Epoch: 940 | Train Loss: 0.44243, Train Acc: 86.29% | Val loss: 0.22306, Val acc: 94.48%
# Epoch: 950 | Train Loss: 0.44295, Train Acc: 86.62% | Val loss: 0.22306, Val acc: 94.48%
# Epoch: 960 | Train Loss: 0.43904, Train Acc: 86.58% | Val loss: 0.22261, Val acc: 94.60%
# Epoch: 970 | Train Loss: 0.43909, Train Acc: 86.71% | Val loss: 0.22275, Val acc: 94.50%
# Epoch: 980 | Train Loss: 0.45112, Train Acc: 86.32% | Val loss: 0.22255, Val acc: 94.50%
# Epoch: 990 | Train Loss: 0.43894, Train Acc: 86.63% | Val loss: 0.22290, Val acc: 94.53%
# Epoch: 1000 | Train Loss: 0.44545, Train Acc: 86.58% | Val loss: 0.22294, Val acc: 94.57%
# Epoch: 1010 | Train Loss: 0.44624, Train Acc: 86.37% | Val loss: 0.22348, Val acc: 94.57%
# Epoch: 1020 | Train Loss: 0.44115, Train Acc: 86.54% | Val loss: 0.22291, Val acc: 94.54%
# Epoch: 1030 | Train Loss: 0.44222, Train Acc: 86.47% | Val loss: 0.22248, Val acc: 94.54%
# Epoch: 1040 | Train Loss: 0.44418, Train Acc: 86.46% | Val loss: 0.22268, Val acc: 94.61%
# Epoch: 1050 | Train Loss: 0.44138, Train Acc: 86.49% | Val loss: 0.22323, Val acc: 94.57%
# Epoch: 1060 | Train Loss: 0.43746, Train Acc: 86.78% | Val loss: 0.22304, Val acc: 94.57%
# Epoch: 1070 | Train Loss: 0.44184, Train Acc: 86.49% | Val loss: 0.22319, Val acc: 94.54%
# Epoch: 1080 | Train Loss: 0.44065, Train Acc: 86.43% | Val loss: 0.22291, Val acc: 94.62%
# Epoch: 1090 | Train Loss: 0.44306, Train Acc: 86.39% | Val loss: 0.22313, Val acc: 94.57%
# Epoch: 1100 | Train Loss: 0.44496, Train Acc: 86.35% | Val loss: 0.22321, Val acc: 94.53%
# Epoch: 1110 | Train Loss: 0.44562, Train Acc: 86.42% | Val loss: 0.22305, Val acc: 94.55%
# Epoch: 1120 | Train Loss: 0.44529, Train Acc: 86.39% | Val loss: 0.22331, Val acc: 94.61%
# Epoch: 1130 | Train Loss: 0.44614, Train Acc: 86.47% | Val loss: 0.22319, Val acc: 94.51%
# Epoch: 1140 | Train Loss: 0.44400, Train Acc: 86.60% | Val loss: 0.22292, Val acc: 94.55%
# Epoch: 1150 | Train Loss: 0.44379, Train Acc: 86.52% | Val loss: 0.22282, Val acc: 94.48%
# Epoch: 1160 | Train Loss: 0.44329, Train Acc: 86.59% | Val loss: 0.22345, Val acc: 94.50%
# Epoch: 1170 | Train Loss: 0.44311, Train Acc: 86.44% | Val loss: 0.22271, Val acc: 94.50%
# Epoch: 1180 | Train Loss: 0.44262, Train Acc: 86.51% | Val loss: 0.22311, Val acc: 94.55%
# Epoch: 1190 | Train Loss: 0.44444, Train Acc: 86.51% | Val loss: 0.22347, Val acc: 94.61%
# Epoch: 1200 | Train Loss: 0.44278, Train Acc: 86.47% | Val loss: 0.22302, Val acc: 94.54%
# Epoch: 1210 | Train Loss: 0.44384, Train Acc: 86.56% | Val loss: 0.22360, Val acc: 94.54%
# Epoch: 1220 | Train Loss: 0.44857, Train Acc: 86.25% | Val loss: 0.22305, Val acc: 94.61%
# Epoch: 1230 | Train Loss: 0.44323, Train Acc: 86.43% | Val loss: 0.22329, Val acc: 94.53%
# Epoch: 1240 | Train Loss: 0.44138, Train Acc: 86.75% | Val loss: 0.22299, Val acc: 94.50%
# Epoch: 1250 | Train Loss: 0.44315, Train Acc: 86.57% | Val loss: 0.22295, Val acc: 94.50%
# Epoch: 1260 | Train Loss: 0.44542, Train Acc: 86.26% | Val loss: 0.22249, Val acc: 94.48%
# Epoch: 1270 | Train Loss: 0.44216, Train Acc: 86.32% | Val loss: 0.22292, Val acc: 94.53%
# Epoch: 1280 | Train Loss: 0.44327, Train Acc: 86.55% | Val loss: 0.22317, Val acc: 94.54%
# Epoch: 1290 | Train Loss: 0.44319, Train Acc: 86.50% | Val loss: 0.22332, Val acc: 94.51%
# Epoch: 1300 | Train Loss: 0.44153, Train Acc: 86.60% | Val loss: 0.22255, Val acc: 94.57%
# Epoch: 1310 | Train Loss: 0.44035, Train Acc: 86.58% | Val loss: 0.22297, Val acc: 94.54%
# Epoch: 1320 | Train Loss: 0.44866, Train Acc: 86.22% | Val loss: 0.22289, Val acc: 94.58%
# Epoch: 1330 | Train Loss: 0.44255, Train Acc: 86.33% | Val loss: 0.22193, Val acc: 94.51%
# Epoch: 1340 | Train Loss: 0.44281, Train Acc: 86.34% | Val loss: 0.22358, Val acc: 94.54%
# Epoch: 1350 | Train Loss: 0.44132, Train Acc: 86.54% | Val loss: 0.22284, Val acc: 94.53%
# Epoch: 1360 | Train Loss: 0.44476, Train Acc: 86.33% | Val loss: 0.22356, Val acc: 94.62%
# Epoch: 1370 | Train Loss: 0.44291, Train Acc: 86.40% | Val loss: 0.22311, Val acc: 94.53%
# Epoch: 1380 | Train Loss: 0.44348, Train Acc: 86.46% | Val loss: 0.22272, Val acc: 94.48%
# Epoch: 1390 | Train Loss: 0.44039, Train Acc: 86.80% | Val loss: 0.22255, Val acc: 94.53%
# Epoch: 1400 | Train Loss: 0.43816, Train Acc: 86.71% | Val loss: 0.22230, Val acc: 94.48%
# Epoch: 1410 | Train Loss: 0.44421, Train Acc: 86.29% | Val loss: 0.22279, Val acc: 94.58%
# Epoch: 1420 | Train Loss: 0.44431, Train Acc: 86.39% | Val loss: 0.22335, Val acc: 94.51%
# Epoch: 1430 | Train Loss: 0.44155, Train Acc: 86.63% | Val loss: 0.22266, Val acc: 94.54%
# Epoch: 1440 | Train Loss: 0.44109, Train Acc: 86.58% | Val loss: 0.22359, Val acc: 94.50%
# Epoch: 1450 | Train Loss: 0.44243, Train Acc: 86.48% | Val loss: 0.22287, Val acc: 94.51%
# Epoch: 1460 | Train Loss: 0.44563, Train Acc: 86.31% | Val loss: 0.22304, Val acc: 94.62%
# Epoch: 1470 | Train Loss: 0.44494, Train Acc: 86.60% | Val loss: 0.22218, Val acc: 94.51%
# Epoch: 1480 | Train Loss: 0.43889, Train Acc: 86.59% | Val loss: 0.22332, Val acc: 94.57%
# Epoch: 1490 | Train Loss: 0.43957, Train Acc: 86.60% | Val loss: 0.22324, Val acc: 94.57%
# Epoch: 1500 | Train Loss: 0.44034, Train Acc: 86.70% | Val loss: 0.22311, Val acc: 94.54%
# Epoch: 1510 | Train Loss: 0.44613, Train Acc: 86.50% | Val loss: 0.22326, Val acc: 94.57%
# Epoch: 1520 | Train Loss: 0.44458, Train Acc: 86.35% | Val loss: 0.22289, Val acc: 94.57%
# Epoch: 1530 | Train Loss: 0.43866, Train Acc: 86.62% | Val loss: 0.22216, Val acc: 94.54%
# Epoch: 1540 | Train Loss: 0.44491, Train Acc: 86.60% | Val loss: 0.22256, Val acc: 94.53%
# Epoch: 1550 | Train Loss: 0.44328, Train Acc: 86.42% | Val loss: 0.22224, Val acc: 94.60%
# Epoch: 1560 | Train Loss: 0.44079, Train Acc: 86.61% | Val loss: 0.22299, Val acc: 94.54%
# Epoch: 1570 | Train Loss: 0.44325, Train Acc: 86.56% | Val loss: 0.22273, Val acc: 94.53%
# Epoch: 1580 | Train Loss: 0.44346, Train Acc: 86.51% | Val loss: 0.22296, Val acc: 94.60%
# Epoch: 1590 | Train Loss: 0.44112, Train Acc: 86.80% | Val loss: 0.22318, Val acc: 94.57%
# Epoch: 1600 | Train Loss: 0.44227, Train Acc: 86.39% | Val loss: 0.22311, Val acc: 94.57%
# Epoch: 1610 | Train Loss: 0.43796, Train Acc: 86.67% | Val loss: 0.22242, Val acc: 94.58%
# Epoch: 1620 | Train Loss: 0.44244, Train Acc: 86.52% | Val loss: 0.22240, Val acc: 94.68%
# Epoch: 1630 | Train Loss: 0.44023, Train Acc: 86.64% | Val loss: 0.22279, Val acc: 94.58%
# Epoch: 1640 | Train Loss: 0.44403, Train Acc: 86.44% | Val loss: 0.22244, Val acc: 94.48%
# Epoch: 1650 | Train Loss: 0.44326, Train Acc: 86.60% | Val loss: 0.22302, Val acc: 94.51%
# Epoch: 1660 | Train Loss: 0.44465, Train Acc: 86.32% | Val loss: 0.22273, Val acc: 94.54%
# Epoch: 1670 | Train Loss: 0.44101, Train Acc: 86.50% | Val loss: 0.22276, Val acc: 94.58%
# Epoch: 1680 | Train Loss: 0.44393, Train Acc: 86.29% | Val loss: 0.22266, Val acc: 94.53%
# Epoch: 1690 | Train Loss: 0.44838, Train Acc: 86.32% | Val loss: 0.22330, Val acc: 94.55%
# Epoch: 1700 | Train Loss: 0.44358, Train Acc: 86.41% | Val loss: 0.22264, Val acc: 94.53%
# Epoch: 1710 | Train Loss: 0.44667, Train Acc: 86.45% | Val loss: 0.22291, Val acc: 94.53%
# Epoch: 1720 | Train Loss: 0.44033, Train Acc: 86.48% | Val loss: 0.22287, Val acc: 94.51%
# Epoch: 1730 | Train Loss: 0.44063, Train Acc: 86.55% | Val loss: 0.22195, Val acc: 94.50%
# Epoch: 1740 | Train Loss: 0.44265, Train Acc: 86.45% | Val loss: 0.22265, Val acc: 94.51%
# Epoch: 1750 | Train Loss: 0.44307, Train Acc: 86.45% | Val loss: 0.22241, Val acc: 94.54%
# Epoch: 1760 | Train Loss: 0.44103, Train Acc: 86.51% | Val loss: 0.22272, Val acc: 94.57%
# Epoch: 1770 | Train Loss: 0.44192, Train Acc: 86.17% | Val loss: 0.22274, Val acc: 94.53%
# Epoch: 1780 | Train Loss: 0.44148, Train Acc: 86.64% | Val loss: 0.22266, Val acc: 94.57%
# Epoch: 1790 | Train Loss: 0.44041, Train Acc: 86.63% | Val loss: 0.22274, Val acc: 94.55%
# Epoch: 1800 | Train Loss: 0.44070, Train Acc: 86.69% | Val loss: 0.22278, Val acc: 94.54%
# Epoch: 1810 | Train Loss: 0.43946, Train Acc: 86.51% | Val loss: 0.22274, Val acc: 94.58%
# Epoch: 1820 | Train Loss: 0.43396, Train Acc: 86.92% | Val loss: 0.22263, Val acc: 94.58%
# Epoch: 1830 | Train Loss: 0.44610, Train Acc: 86.23% | Val loss: 0.22364, Val acc: 94.61%
# Epoch: 1840 | Train Loss: 0.44443, Train Acc: 86.43% | Val loss: 0.22240, Val acc: 94.55%
# Epoch: 1850 | Train Loss: 0.44123, Train Acc: 86.58% | Val loss: 0.22316, Val acc: 94.54%
# Epoch: 1860 | Train Loss: 0.44093, Train Acc: 86.50% | Val loss: 0.22283, Val acc: 94.57%
# Epoch: 1870 | Train Loss: 0.44385, Train Acc: 86.31% | Val loss: 0.22245, Val acc: 94.51%
# Epoch: 1880 | Train Loss: 0.44069, Train Acc: 86.61% | Val loss: 0.22274, Val acc: 94.55%
# Epoch: 1890 | Train Loss: 0.44342, Train Acc: 86.52% | Val loss: 0.22213, Val acc: 94.51%
# Epoch: 1900 | Train Loss: 0.44549, Train Acc: 86.55% | Val loss: 0.22288, Val acc: 94.53%
# Epoch: 1910 | Train Loss: 0.44283, Train Acc: 86.63% | Val loss: 0.22311, Val acc: 94.58%
# Epoch: 1920 | Train Loss: 0.44632, Train Acc: 86.52% | Val loss: 0.22266, Val acc: 94.48%
# Epoch: 1930 | Train Loss: 0.44287, Train Acc: 86.52% | Val loss: 0.22339, Val acc: 94.54%
# Epoch: 1940 | Train Loss: 0.44364, Train Acc: 86.36% | Val loss: 0.22310, Val acc: 94.54%
# Epoch: 1950 | Train Loss: 0.44208, Train Acc: 86.43% | Val loss: 0.22287, Val acc: 94.51%
# Epoch: 1960 | Train Loss: 0.44350, Train Acc: 86.27% | Val loss: 0.22267, Val acc: 94.48%
# Epoch: 1970 | Train Loss: 0.44182, Train Acc: 86.59% | Val loss: 0.22246, Val acc: 94.58%
# Epoch: 1980 | Train Loss: 0.44744, Train Acc: 86.34% | Val loss: 0.22264, Val acc: 94.54%
# Epoch: 1990 | Train Loss: 0.44130, Train Acc: 86.24% | Val loss: 0.22307, Val acc: 94.60%
# Epoch: 2000 | Train Loss: 0.44304, Train Acc: 86.50% | Val loss: 0.22243, Val acc: 94.64%
# Epoch: 2010 | Train Loss: 0.43980, Train Acc: 86.42% | Val loss: 0.22361, Val acc: 94.58%
# Epoch: 2020 | Train Loss: 0.43731, Train Acc: 86.87% | Val loss: 0.22216, Val acc: 94.57%
# Epoch: 2030 | Train Loss: 0.44584, Train Acc: 86.29% | Val loss: 0.22309, Val acc: 94.55%
# Epoch: 2040 | Train Loss: 0.44411, Train Acc: 86.48% | Val loss: 0.22262, Val acc: 94.58%
# Epoch: 2050 | Train Loss: 0.44512, Train Acc: 86.54% | Val loss: 0.22322, Val acc: 94.58%
# Epoch: 2060 | Train Loss: 0.44938, Train Acc: 86.29% | Val loss: 0.22251, Val acc: 94.54%
# Epoch: 2070 | Train Loss: 0.44332, Train Acc: 86.35% | Val loss: 0.22247, Val acc: 94.50%
# Epoch: 2080 | Train Loss: 0.43943, Train Acc: 86.67% | Val loss: 0.22229, Val acc: 94.51%
# Epoch: 2090 | Train Loss: 0.44273, Train Acc: 86.38% | Val loss: 0.22217, Val acc: 94.54%
# Epoch: 2100 | Train Loss: 0.44370, Train Acc: 86.59% | Val loss: 0.22289, Val acc: 94.53%
# Epoch: 2110 | Train Loss: 0.44245, Train Acc: 86.35% | Val loss: 0.22201, Val acc: 94.55%
# Epoch: 2120 | Train Loss: 0.44446, Train Acc: 86.12% | Val loss: 0.22305, Val acc: 94.60%
# Epoch: 2130 | Train Loss: 0.44334, Train Acc: 86.37% | Val loss: 0.22238, Val acc: 94.55%
# Epoch: 2140 | Train Loss: 0.44521, Train Acc: 86.30% | Val loss: 0.22299, Val acc: 94.55%
# Epoch: 2150 | Train Loss: 0.43933, Train Acc: 86.66% | Val loss: 0.22237, Val acc: 94.48%
# Epoch: 2160 | Train Loss: 0.44318, Train Acc: 86.42% | Val loss: 0.22264, Val acc: 94.55%
# Epoch: 2170 | Train Loss: 0.44363, Train Acc: 86.57% | Val loss: 0.22230, Val acc: 94.71%
# Epoch: 2180 | Train Loss: 0.44074, Train Acc: 86.46% | Val loss: 0.22306, Val acc: 94.55%
# Epoch: 2190 | Train Loss: 0.43612, Train Acc: 86.79% | Val loss: 0.22280, Val acc: 94.57%
# Epoch: 2200 | Train Loss: 0.44521, Train Acc: 86.52% | Val loss: 0.22232, Val acc: 94.61%
# Epoch: 2210 | Train Loss: 0.45027, Train Acc: 86.24% | Val loss: 0.22195, Val acc: 94.53%
# Epoch: 2220 | Train Loss: 0.44425, Train Acc: 86.26% | Val loss: 0.22270, Val acc: 94.53%
# Epoch: 2230 | Train Loss: 0.44248, Train Acc: 86.52% | Val loss: 0.22291, Val acc: 94.57%
# Epoch: 2240 | Train Loss: 0.43958, Train Acc: 86.62% | Val loss: 0.22305, Val acc: 94.57%
# Epoch: 2250 | Train Loss: 0.43920, Train Acc: 86.62% | Val loss: 0.22295, Val acc: 94.55%
# Epoch: 2260 | Train Loss: 0.44976, Train Acc: 86.22% | Val loss: 0.22227, Val acc: 94.58%
# Epoch: 2270 | Train Loss: 0.44033, Train Acc: 86.71% | Val loss: 0.22309, Val acc: 94.61%
# Epoch: 2280 | Train Loss: 0.44201, Train Acc: 86.33% | Val loss: 0.22273, Val acc: 94.50%
# Epoch: 2290 | Train Loss: 0.43989, Train Acc: 86.60% | Val loss: 0.22266, Val acc: 94.55%
# Epoch: 2300 | Train Loss: 0.43753, Train Acc: 86.84% | Val loss: 0.22223, Val acc: 94.54%
# Epoch: 2310 | Train Loss: 0.43888, Train Acc: 86.94% | Val loss: 0.22244, Val acc: 94.57%
# Epoch: 2320 | Train Loss: 0.44417, Train Acc: 86.52% | Val loss: 0.22311, Val acc: 94.60%
# Epoch: 2330 | Train Loss: 0.44125, Train Acc: 86.38% | Val loss: 0.22277, Val acc: 94.54%
# Epoch: 2340 | Train Loss: 0.43897, Train Acc: 86.76% | Val loss: 0.22320, Val acc: 94.55%
# Epoch: 2350 | Train Loss: 0.44136, Train Acc: 86.66% | Val loss: 0.22247, Val acc: 94.53%
# Epoch: 2360 | Train Loss: 0.43809, Train Acc: 86.77% | Val loss: 0.22252, Val acc: 94.58%
# Epoch: 2370 | Train Loss: 0.44187, Train Acc: 86.38% | Val loss: 0.22229, Val acc: 94.55%
# Epoch: 2380 | Train Loss: 0.44511, Train Acc: 86.48% | Val loss: 0.22283, Val acc: 94.54%
# Epoch: 2390 | Train Loss: 0.43918, Train Acc: 86.36% | Val loss: 0.22275, Val acc: 94.54%
# Epoch: 2400 | Train Loss: 0.43812, Train Acc: 86.72% | Val loss: 0.22266, Val acc: 94.61%
# Epoch: 2410 | Train Loss: 0.43853, Train Acc: 86.59% | Val loss: 0.22213, Val acc: 94.55%
# Epoch: 2420 | Train Loss: 0.43930, Train Acc: 86.86% | Val loss: 0.22192, Val acc: 94.53%
# Epoch: 2430 | Train Loss: 0.44250, Train Acc: 86.30% | Val loss: 0.22212, Val acc: 94.58%
# Epoch: 2440 | Train Loss: 0.44300, Train Acc: 86.53% | Val loss: 0.22320, Val acc: 94.61%
# Epoch: 2450 | Train Loss: 0.44371, Train Acc: 86.41% | Val loss: 0.22263, Val acc: 94.51%
# Epoch: 2460 | Train Loss: 0.44598, Train Acc: 86.31% | Val loss: 0.22304, Val acc: 94.54%
# Epoch: 2470 | Train Loss: 0.43945, Train Acc: 86.47% | Val loss: 0.22262, Val acc: 94.57%
# Epoch: 2480 | Train Loss: 0.44168, Train Acc: 86.66% | Val loss: 0.22354, Val acc: 94.55%
# Epoch: 2490 | Train Loss: 0.44554, Train Acc: 86.41% | Val loss: 0.22230, Val acc: 94.55%
# Epoch: 2500 | Train Loss: 0.43624, Train Acc: 86.82% | Val loss: 0.22346, Val acc: 94.57%
# Epoch: 2510 | Train Loss: 0.43756, Train Acc: 87.00% | Val loss: 0.22250, Val acc: 94.57%
# Epoch: 2520 | Train Loss: 0.44231, Train Acc: 86.53% | Val loss: 0.22231, Val acc: 94.61%
# Epoch: 2530 | Train Loss: 0.44183, Train Acc: 86.47% | Val loss: 0.22328, Val acc: 94.55%
# Epoch: 2540 | Train Loss: 0.44274, Train Acc: 86.43% | Val loss: 0.22258, Val acc: 94.53%
# Epoch: 2550 | Train Loss: 0.44132, Train Acc: 86.60% | Val loss: 0.22298, Val acc: 94.55%
# Epoch: 2560 | Train Loss: 0.44030, Train Acc: 86.75% | Val loss: 0.22203, Val acc: 94.58%
# Epoch: 2570 | Train Loss: 0.43970, Train Acc: 86.91% | Val loss: 0.22196, Val acc: 94.53%
# Epoch: 2580 | Train Loss: 0.43947, Train Acc: 86.45% | Val loss: 0.22249, Val acc: 94.50%
# Epoch: 2590 | Train Loss: 0.44079, Train Acc: 86.37% | Val loss: 0.22224, Val acc: 94.57%
# Epoch: 2600 | Train Loss: 0.44052, Train Acc: 86.69% | Val loss: 0.22332, Val acc: 94.55%
# Epoch: 2610 | Train Loss: 0.44212, Train Acc: 86.65% | Val loss: 0.22302, Val acc: 94.58%
# Epoch: 2620 | Train Loss: 0.44067, Train Acc: 86.61% | Val loss: 0.22275, Val acc: 94.54%
# Epoch: 2630 | Train Loss: 0.45012, Train Acc: 86.09% | Val loss: 0.22247, Val acc: 94.55%
# Epoch: 2640 | Train Loss: 0.43953, Train Acc: 86.37% | Val loss: 0.22260, Val acc: 94.53%
# Epoch: 2650 | Train Loss: 0.44334, Train Acc: 86.60% | Val loss: 0.22231, Val acc: 94.48%
# Epoch: 2660 | Train Loss: 0.44782, Train Acc: 86.16% | Val loss: 0.22229, Val acc: 94.54%
# Epoch: 2670 | Train Loss: 0.43872, Train Acc: 86.74% | Val loss: 0.22265, Val acc: 94.55%
# Epoch: 2680 | Train Loss: 0.43809, Train Acc: 86.56% | Val loss: 0.22217, Val acc: 94.55%
# Epoch: 2690 | Train Loss: 0.44111, Train Acc: 86.43% | Val loss: 0.22236, Val acc: 94.51%
# Epoch: 2700 | Train Loss: 0.44015, Train Acc: 86.60% | Val loss: 0.22285, Val acc: 94.55%
# Epoch: 2710 | Train Loss: 0.44574, Train Acc: 86.41% | Val loss: 0.22206, Val acc: 94.54%
# Epoch: 2720 | Train Loss: 0.44305, Train Acc: 86.64% | Val loss: 0.22255, Val acc: 94.57%
# Epoch: 2730 | Train Loss: 0.43776, Train Acc: 86.31% | Val loss: 0.22280, Val acc: 94.62%
# Epoch: 2740 | Train Loss: 0.44910, Train Acc: 86.18% | Val loss: 0.22350, Val acc: 94.55%
# Epoch: 2750 | Train Loss: 0.44264, Train Acc: 86.64% | Val loss: 0.22208, Val acc: 94.47%
# Epoch: 2760 | Train Loss: 0.43886, Train Acc: 86.55% | Val loss: 0.22226, Val acc: 94.60%
# Epoch: 2770 | Train Loss: 0.44373, Train Acc: 86.58% | Val loss: 0.22240, Val acc: 94.58%
# Epoch: 2780 | Train Loss: 0.44221, Train Acc: 86.43% | Val loss: 0.22295, Val acc: 94.53%
# Epoch: 2790 | Train Loss: 0.44304, Train Acc: 86.60% | Val loss: 0.22262, Val acc: 94.54%
# Epoch: 2800 | Train Loss: 0.44758, Train Acc: 86.38% | Val loss: 0.22250, Val acc: 94.53%
# Epoch: 2810 | Train Loss: 0.43930, Train Acc: 86.37% | Val loss: 0.22183, Val acc: 94.60%
# Epoch: 2820 | Train Loss: 0.44378, Train Acc: 86.54% | Val loss: 0.22215, Val acc: 94.64%
# Epoch: 2830 | Train Loss: 0.44592, Train Acc: 86.24% | Val loss: 0.22252, Val acc: 94.58%
# Epoch: 2840 | Train Loss: 0.44181, Train Acc: 86.52% | Val loss: 0.22251, Val acc: 94.55%
# Epoch: 2850 | Train Loss: 0.44779, Train Acc: 86.20% | Val loss: 0.22252, Val acc: 94.60%
# Epoch: 2860 | Train Loss: 0.44164, Train Acc: 86.67% | Val loss: 0.22295, Val acc: 94.51%
# Epoch: 2870 | Train Loss: 0.44379, Train Acc: 86.46% | Val loss: 0.22224, Val acc: 94.60%
# Epoch: 2880 | Train Loss: 0.44117, Train Acc: 86.73% | Val loss: 0.22261, Val acc: 94.53%
# Epoch: 2890 | Train Loss: 0.43952, Train Acc: 86.59% | Val loss: 0.22276, Val acc: 94.53%
# Epoch: 2900 | Train Loss: 0.44448, Train Acc: 86.47% | Val loss: 0.22233, Val acc: 94.55%
# Epoch: 2910 | Train Loss: 0.44209, Train Acc: 86.49% | Val loss: 0.22270, Val acc: 94.57%
# Epoch: 2920 | Train Loss: 0.43651, Train Acc: 86.66% | Val loss: 0.22238, Val acc: 94.58%
# Epoch: 2930 | Train Loss: 0.44284, Train Acc: 86.45% | Val loss: 0.22258, Val acc: 94.55%
# Epoch: 2940 | Train Loss: 0.44062, Train Acc: 86.66% | Val loss: 0.22262, Val acc: 94.54%
# Epoch: 2950 | Train Loss: 0.44371, Train Acc: 86.56% | Val loss: 0.22291, Val acc: 94.61%
# Epoch: 2960 | Train Loss: 0.43603, Train Acc: 86.65% | Val loss: 0.22203, Val acc: 94.58%
# Epoch: 2970 | Train Loss: 0.44317, Train Acc: 86.41% | Val loss: 0.22233, Val acc: 94.51%
# Epoch: 2980 | Train Loss: 0.43886, Train Acc: 86.54% | Val loss: 0.22234, Val acc: 94.53%
# Epoch: 2990 | Train Loss: 0.44499, Train Acc: 86.52% | Val loss: 0.22238, Val acc: 94.58%

# %%
plt.figure(figsize=(8, 6))

# Updated to use val_losses to match the previous cell's corrections!
plt.plot(train_losses, label="Train Loss", color='blue', linewidth=2)
plt.plot(val_losses, label="Validation Loss", color='orange', linewidth=2, linestyle='--')

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss Over Epochs")
plt.legend()
plt.grid(True, linestyle=':', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Saving

# %%
def save_model():
    # 1. Save the Model Weights
    model_path = "model.pth"
    torch.save(model_4.state_dict(), model_path)

    # 2. Save the Metadata (Mapping and Feature Order)
    # We save this as a JSON so it's readable by any Python script later
    metadata = {
        "input_features": X_train.shape[1],
        "output_classes": classes,
        "gesture_mapping": {v: k for k, v in mapping.items()}, # {0: 'rock', ...}
        "feature_names": list(X_train.columns),
        "confidence_threshold": 0.82
    }

    with open("model_metadata.json", "w") as f:
        json.dump(metadata, f, indent=4)

    print(f"Model saved to {model_path}")
    print("Metadata and feature order saved to model_metadata.json")

def run_model():
    # 1. Re-define the class (PyTorch needs the architecture definition)
    class RPSModel(nn.Module):
        def __init__(self, input_features, output_features):
            super().__init__()
            self.linear_layer_stack = nn.Sequential(
                nn.Linear(in_features=input_features, out_features=32),
                nn.ReLU(),
                nn.Dropout(p=DROPOUT),

                nn.Linear(in_features=32, out_features=16),
                nn.ReLU(),
                nn.Dropout(p=DROPOUT),

                nn.Linear(in_features=16, out_features=output_features)
            )

        # 3. Define a forward method containing the forward pass computation
        def forward(self, x):
            return self.linear_layer_stack(x)    # ... (paste your RPSModel class code here) ...

    # 2. Load Metadata
    with open("model_metadata.json", "r") as f:
        meta = json.load(f)

    # 3. Instantiate and Load Weights
    loaded_model = RPSModel(input_features=meta["input_features"], 
                            output_features=meta["output_classes"]).to(device)
    loaded_model.load_state_dict(torch.load("model.pth"))
    loaded_model.eval()

    print("Model successfully reconstructed!")

# %%
save_model()
# Out:
# Model saved to model.pth
# Metadata and feature order saved to model_metadata.json

# %% [markdown]
# # Testing

# %%
# 1. Safely copy the test set to avoid modifying the original data
testing_prep = testing.copy()

# 2. Apply the dynamic mapping we generated earlier
testing_prep["label"] = testing_prep["label"].map(mapping)

# 3. Setup Visualization Constants
# Define display labels FIRST
display_labels = ["Paper", "Rock", "Scissors", "None"]
num_classes = len(display_labels)

# Use modern matplotlib syntax
cmap = plt.colormaps.get_cmap("gist_rainbow")

# Generate exactly 4 colors based on the length of your display labels
colors = cmap(np.linspace(0, 1, num_classes))

# Set confidence threshold for predictions
conf_thres = 0.7

# %%
# ------------------------
# Prepare Test Features
# ------------------------
true_labels1 = testing_prep['label'] # Using the safely copied dataframe from the previous cell
X_features = testing_prep.drop(columns=['label'])

# Vectorized coercion (much faster than a for loop)
X_features = X_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# Align columns with the training data's features (Update the variable name here if needed)
# Use the pandas DataFrame from earlier in your pipeline
X_features = X_features[X_train.columns]

X_new = torch.tensor(X_features.values, dtype=torch.float32).to(device)

# ------------------------
# Inference
# ------------------------
model_4.eval()
with torch.inference_mode():
    new_logits = model_4(X_new)
    new_probs = torch.softmax(new_logits, dim=1)
    # Get the highest probability and the corresponding class index
    max_probs, max_classes = torch.max(new_probs, dim=1)

# Convert to numpy for matplotlib and thresholding
max_probs = max_probs.cpu().numpy()
max_classes = max_classes.cpu().numpy()
true_numeric1 = true_labels1.reset_index(drop=True).values

# ------------------------
# Prepare thresholded predictions (FIXED LOGIC)
# ------------------------
pred_classes_thresh = max_classes.copy()

# Look up the actual integer mapped to 'none' in your dictionary (it should be 3)
existing_none_idx = mapping.get('none', 3) 

# If confidence is below threshold, set prediction to the existing 'none' class
pred_classes_thresh[max_probs < conf_thres] = existing_none_idx

# ------------------------
# Create 3 subplots
# ------------------------
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 12))

# Ensure max_classes is integers, not floats
max_classes = max_classes.astype(int)
pred_classes_thresh = pred_classes_thresh.astype(int)

# ------------------------
# Plot 1: Updated Loop
# ------------------------
for label, class_idx in mapping.items(): # mapping.items() gives (str, int)
    mask = (max_classes == class_idx)
    indices = np.flatnonzero(mask)
    
    # We use the label in the scatter call so the legend picks it up
    color = plt.colormaps.get_cmap("gist_rainbow")(class_idx / len(mapping))
    
    if len(indices) > 0:
        ax1.scatter(
            indices, 
            max_probs[indices], 
            s=12, 
            alpha=0.8, 
            label=label, # This is what the legend looks for!
            color=color
        )

# Check if anything was actually plotted before calling legend to avoid the warning
if ax1.get_legend_handles_labels()[0]:
    ax1.legend()

# ------------------------
# Plot 2: Updated Loop
# ------------------------
for label, class_idx in mapping.items():
    mask = (pred_classes_thresh == class_idx)
    indices = np.flatnonzero(mask)
    
    color = plt.colormaps.get_cmap("gist_rainbow")(class_idx / len(mapping))
    
    if len(indices) > 0:
        ax2.scatter(
            indices, 
            max_probs[indices], 
            s=12, 
            alpha=0.8, 
            label=label, 
            color=color
        )

if ax2.get_legend_handles_labels()[0]:
    ax2.legend()
# ------------------------
# Plot 3: Correct vs Incorrect (threshold applied)
# ------------------------
correct_mask_thresh = pred_classes_thresh == true_numeric1
incorrect_mask_thresh = pred_classes_thresh != true_numeric1

correct_idx = np.flatnonzero(correct_mask_thresh)
incorrect_idx = np.flatnonzero(incorrect_mask_thresh)

ax3.scatter(correct_idx, max_probs[correct_idx], s=12, alpha=0.8, label="Correct", color="green")
ax3.scatter(incorrect_idx, max_probs[incorrect_idx], s=12, alpha=0.8, label="Incorrect", color="red")

ax3.set_xlabel("Sample Index")
ax3.set_ylabel("Max Confidence")
ax3.set_ylim(0, 1.1)
ax3.set_title("Prediction Accuracy (After Threshold Applied)")
ax3.axhline(y=conf_thres, color='black', linestyle='--', linewidth=1)
ax3.legend()
ax3.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Live Data Sim

# %%
# 1. Load and clean
df_test = pd.read_csv("data/Glove_v2_norm/output_norm_test.csv", sep=",")
df_test = df_test.iloc[1:].copy() # Use .copy() to avoid SettingWithCopyWarnings

# %%
df_test.head()
# Out:
#    0.000292  BNO0_UnitAccX  BNO0_UnitAccY  BNO0_UnitAccZ  BNO0_RawAccMag  \
# 1  0.000569         -0.381          0.912         -0.153         2484.01
# 2  0.000669         -0.378          0.914         -0.150         2478.17
# 3  0.000759         -0.378          0.913         -0.157         2481.08
# 4  0.000844         -0.376          0.914         -0.154         2466.78
# 5  0.000928         -0.380          0.911         -0.162         2464.45
#
#    BNO0_GyrX  BNO0_GyrY  BNO0_GyrZ  BNO0_MagX  BNO0_MagY  ...  MPU0_GyrY  \
# 1     -0.671      0.000     -0.224     -0.293     -0.954  ...     -0.046
# 2     -0.336      0.000      0.112     -0.298     -0.954  ...      0.107
# 3     -0.112     -0.112     -0.112     -0.297     -0.954  ...     -0.504
# 4     -0.336     -0.112     -0.336     -0.302     -0.953  ...     -2.351
# 5     -1.343     -1.119     -1.231     -0.293     -0.954  ...     -5.267
#
#    MPU0_GyrZ  MPU1_UnitAccX  MPU1_UnitAccY  MPU1_UnitAccZ  MPU1_RawAccMag  \
# 1     -1.588          0.948         -0.280         -0.153          10.636
# 2     -1.405          0.949         -0.279         -0.148          10.590
# 3     -1.176          0.948         -0.281         -0.147          10.597
# 4     -0.672          0.948         -0.283         -0.143          10.536
# 5      0.305          0.947         -0.290         -0.138          10.471
#
#    MPU1_GyrX  MPU1_GyrY  MPU1_GyrZ  label
# 1     -5.511     -4.885     -1.008   none
# 2     -5.603     -4.733     -0.794   none
# 3     -5.664     -5.191     -0.214   none
# 4     -5.817     -6.595      0.931   none
# 5     -6.244     -8.870      2.916   none
#
# [5 rows x 56 columns]

# %%
# # 1. Clean the data based on movement intensity
# df_test = filter_gyro_spikes(df_test, threshold=150.0)

# 2. Strip the gyro features if you want a purely static-pose model
df_test = drop_gyro_columns(df_test)

# 3. Get mean and variance
#df_test = get_window_data(df_test, 5)
# Out:
# Dropped 18 gyroscope columns.

# %%
# 2. Safe dropping and renaming
# Replace '0' with the actual column name if it's a string like "Time"
df_test = df_test.drop(columns=[df_test.columns[0]], errors='ignore') 
df_test.rename(columns={df_test.columns[-1]: 'label'}, inplace=True)

# 3. Bulletproof label mapping
# mapping2 = {'paper': 0, 'rock': 1, 'scissors': 2, 'none': 3}
mapping2 = mapping.copy()
# mapping2["none"] = 3
df_test["label"] = df_test["label"].astype(str).str.strip().str.lower().map(mapping2)

# 4. Visualization Setup (ORDER MATTERS!)
display_labels = ["Paper", "Rock", "Scissors", "None"]
num_classes = len(display_labels)
conf_thres = 0.6

# Generate exactly 4 colors
cmap = plt.colormaps.get_cmap("gist_rainbow")
colors = cmap(np.linspace(0, 1, num_classes))

# Assign to your testing variable
testing2 = df_test

# %%
df_train.head()
# Out:
#    BNO0_UnitAccX  BNO0_UnitAccY  BNO0_UnitAccZ  BNO0_RawAccMag  BNO0_MagX  \
# 0       0.796921       0.542167       0.265868     2458.124868  -0.747368
# 1       0.188000       0.350000      -0.918000     2510.560000  -0.561000
# 2       0.679031       0.519031      -0.520061     2462.570715  -0.896962
# 3       0.102937       0.958109      -0.269014     2451.908180  -0.378137
# 4      -0.234051       0.900002      -0.368158     2464.003119  -0.198193
#
#    BNO0_MagY  BNO0_MagZ  BNO1_UnitAccX  BNO1_UnitAccY  BNO1_UnitAccZ  ...  \
# 0  -0.229208  -0.623916       0.915029       0.390113       0.100753  ...
# 1  -0.348000   0.751000      -0.145000      -0.190000      -0.971000  ...
# 2  -0.411089   0.160912       0.890868       0.399544      -0.213074  ...
# 3  -0.899251   0.222827       0.065987       0.655842      -0.752076  ...
# 4  -0.933059   0.298874      -0.190869       0.844148      -0.501250  ...
#
#    BNO3_MagZ  MPU0_UnitAccX  MPU0_UnitAccY  MPU0_UnitAccZ  MPU0_RawAccMag  \
# 0   0.968871       0.486895       0.817419      -0.310052        9.832474
# 1   0.925000       0.866000      -0.226000       0.447000       10.459000
# 2   0.948622       0.845696       0.258455       0.470180       10.462179
# 3  -0.319360       0.952600      -0.151691       0.263380       10.347815
# 4  -0.347933       0.969158       0.015095       0.239968       10.325441
#
#    MPU1_UnitAccX  MPU1_UnitAccY  MPU1_UnitAccZ  MPU1_RawAccMag     label
# 0       0.179368       0.768628      -0.614554       10.481181      none
# 1       0.856000       0.500000       0.130000       10.435000         X
# 2       0.783623       0.620730       0.029617       10.401189         A
# 3       0.970295      -0.029596      -0.233304       10.674798  scissors
# 4       0.919491       0.112465      -0.372240       10.760145      rock
#
# [5 rows x 37 columns]

# %%
df_test.head()
# Out:
#    BNO0_UnitAccX  BNO0_UnitAccY  BNO0_UnitAccZ  BNO0_RawAccMag  BNO0_MagX  \
# 1         -0.381          0.912         -0.153         2484.01     -0.293
# 2         -0.378          0.914         -0.150         2478.17     -0.298
# 3         -0.378          0.913         -0.157         2481.08     -0.297
# 4         -0.376          0.914         -0.154         2466.78     -0.302
# 5         -0.380          0.911         -0.162         2464.45     -0.293
#
#    BNO0_MagY  BNO0_MagZ  BNO1_UnitAccX  BNO1_UnitAccY  BNO1_UnitAccZ  ...  \
# 1     -0.954     -0.058         -0.280          0.952         -0.124  ...
# 2     -0.954     -0.037         -0.277          0.954         -0.112  ...
# 3     -0.954     -0.048         -0.278          0.953         -0.124  ...
# 4     -0.953     -0.029         -0.275          0.953         -0.129  ...
# 5     -0.954     -0.063         -0.276          0.952         -0.133  ...
#
#    BNO3_MagZ  MPU0_UnitAccX  MPU0_UnitAccY  MPU0_UnitAccZ  MPU0_RawAccMag  \
# 1      0.722          0.945         -0.304         -0.117          10.038
# 2      0.717          0.945         -0.306         -0.115          10.027
# 3      0.723          0.944         -0.308         -0.115           9.987
# 4      0.722          0.943         -0.313         -0.112           9.930
# 5      0.728          0.942         -0.318         -0.111           9.893
#
#    MPU1_UnitAccX  MPU1_UnitAccY  MPU1_UnitAccZ  MPU1_RawAccMag  label
# 1          0.948         -0.280         -0.153          10.636      4
# 2          0.949         -0.279         -0.148          10.590      4
# 3          0.948         -0.281         -0.147          10.597      4
# 4          0.948         -0.283         -0.143          10.536      4
# 5          0.947         -0.290         -0.138          10.471      4
#
# [5 rows x 37 columns]

# %%
# ------------------------
# 1. Prepare Test Features
# ------------------------
# Use the testing2 dataframe we loaded from the new CSV
true_labels2 = testing2["label"]
X_features = testing2.drop(columns=['label'], errors='ignore')

# Vectorized coercion to ensure all sensor data is numeric
X_features = X_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# CRITICAL: Align columns with your ORIGINAL training features
# Replace 'X_train' with whatever your training DataFrame was named (e.g., 'df_train' or 'data')
X_features = X_features[X_train.columns] 

# Convert to PyTorch tensor and move to GPU/CPU
X_new = torch.tensor(X_features.values, dtype=torch.float32).to(device)

# ------------------------
# 2. Inference
# ------------------------
model_4.eval()
with torch.inference_mode():
    new_logits = model_4(X_new)
    new_probs = torch.softmax(new_logits, dim=1)
    # Get the highest probability and the corresponding class index
    max_probs, max_classes = torch.max(new_probs, dim=1)

# Convert tensors to CPU numpy for thresholding and plotting
max_probs = max_probs.cpu().numpy()
max_classes = max_classes.cpu().numpy().astype(int)
true_numeric2 = true_labels2.reset_index(drop=True).values.astype(int)

# ------------------------
# 3. Thresholding Logic (Fixed)
# ------------------------
pred_classes_thresh = max_classes.copy()
# Map low confidence to the EXISTING 'none' index (usually 3)
none_class_idx = mapping.get('none', 3) 
pred_classes_thresh[max_probs < conf_thres] = none_class_idx

# ------------------------
# 4. Visualization (3 Subplots)
# ------------------------
fig, (ax1, ax3, ax2) = plt.subplots(3, 1, figsize=(10, 12))
cmap = plt.colormaps.get_cmap("gist_rainbow")

# Plot 1: Raw Predictions
for label, class_idx in mapping.items():
    mask = (max_classes == class_idx)
    indices = np.flatnonzero(mask)
    if len(indices) == 0: continue
    
    color = cmap(class_idx / len(mapping))
    ax1.scatter(indices, max_probs[indices], s=12, alpha=0.8, label=label, color=color)

ax1.set_ylabel("Max Confidence")
ax1.set_ylim(0, 1.1)
ax1.set_title("Original Predictions – Highest Confidence Class")
ax1.axhline(y=conf_thres, color='black', linestyle='--', linewidth=1)
ax1.legend()
ax1.grid(alpha=0.3)

# Plot 2: Thresholded predictions
for label, class_idx in mapping.items():
    mask = (pred_classes_thresh == class_idx)
    indices = np.flatnonzero(mask)
    if len(indices) == 0: continue
    
    color = cmap(class_idx / len(mapping))
    ax2.scatter(indices, max_probs[indices], s=12, alpha=0.8, label=label, color=color)

ax2.set_ylabel("Max Confidence")
ax2.set_ylim(0, 1.1)
ax2.set_title(f"Threshold Applied ({conf_thres}) - Forced to 'none' if low")
ax2.axhline(y=conf_thres, color='black', linestyle='--', linewidth=1)
ax2.legend()
ax2.grid(alpha=0.3)

# Plot 3: Accuracy (Correct vs Incorrect)
correct_mask = (pred_classes_thresh == true_numeric2)
incorrect_mask = (pred_classes_thresh != true_numeric2)

ax3.scatter(np.flatnonzero(correct_mask), max_probs[correct_mask], 
            s=12, alpha=0.8, label="Correct", color="green")
ax3.scatter(np.flatnonzero(incorrect_mask), max_probs[incorrect_mask], 
            s=12, alpha=0.8, label="Incorrect", color="red")

ax3.set_xlabel("Sample Index")
ax3.set_ylabel("Max Confidence")
ax3.set_ylim(0, 1.1)
ax3.set_title("Prediction Accuracy (After Threshold)")
ax3.axhline(y=conf_thres, color='black', linestyle='--', linewidth=1)
ax3.legend()
ax3.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Confusion Matrix

# %%
true_numeric = true_numeric2

# %%
print(f"Number of NaNs in true_numeric: {np.isnan(true_numeric).sum()}")
# Out:
# Number of NaNs in true_numeric: 0

# %%
# 1. Ensure numeric types and clean NaNs
valid_mask = ~np.isnan(true_numeric2) # Using 'true_numeric2' from your latest test
true_numeric_clean = true_numeric2[valid_mask].astype(int)
max_classes_clean = max_classes[valid_mask].astype(int)

# 2. Calculate the matrix
# Use 'labels' to force the matrix to include all classes even if they weren't predicted
class_indices = list(range(len(mapping)))
cm = confusion_matrix(true_numeric_clean, max_classes_clean, labels=class_indices)

# 3. Plot with normalization ('true' normalizes by rows/actual classes)
fig, ax = plt.subplots(figsize=(8, 8))
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=list(mapping.keys())
)

# Plotting with percentages makes it much easier to read
disp.plot(cmap='Blues', ax=ax, values_format='.1f', xticks_rotation='vertical')

plt.title("Confusion Matrix (Percentages)")
plt.show()

# %%
print("Average Confidence per Predicted Class:\n")

# Use the actual mapping to stay consistent with your 4 classes
for class_name, class_idx in mapping.items():
    # 1. Create a mask for samples assigned to this class (after thresholding)
    class_mask = (pred_classes_thresh == class_idx)

    # 2. Extract the original probabilities for these samples
    confidences_for_class = max_probs[class_mask]

    if len(confidences_for_class) > 0:
        avg_confidence = np.mean(confidences_for_class)
        print(f"{class_name.capitalize()}: {avg_confidence:.4f} (Samples: {len(confidences_for_class)})")
    else:
        print(f"{class_name.capitalize()}: No predictions made for this class.")
# Out:
# Average Confidence per Predicted Class:
#
# A: 0.8048 (Samples: 61)
# B: 0.7807 (Samples: 50)
# X: 0.7159 (Samples: 5)
# Y: 0.6517 (Samples: 5)
# None: 0.8115 (Samples: 1736)
# Paper: 0.9109 (Samples: 382)
# Rock: 0.8376 (Samples: 200)
# Scissors: 0.8852 (Samples: 346)

# %%
# ------------------------
# 1. Prepare Features & Labels
# ------------------------
# Use the mapped labels from your second test set
true_labels = true_numeric2 

X_features = testing2.copy()
X_features = X_features.drop(columns=['label'], errors='ignore')

# Vectorized numeric conversion
X_features = X_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# CRITICAL: Align columns using the original training DataFrame template
# Change 'X_train' to whatever your training features were named (e.g. df_train)
X_features = X_features[X_train.columns] 

# Convert to Tensor for the model
X_new = torch.tensor(X_features.values, dtype=torch.float32).to(device)

# ------------------------
# 2. Model Inference
# ------------------------
model_4.eval()
with torch.inference_mode():
    new_logits = model_4(X_new)
    # ROC curves require probabilities, so we MUST use softmax
    new_probs = torch.softmax(new_logits, dim=1)

# ------------------------
# 3. Data Prep for ROC
# ------------------------
# Move probabilities to CPU numpy for Scikit-Learn
y_score = new_probs.cpu().numpy()

# Convert true labels to One-Hot encoding (Required for Multi-class ROC)
label_binarizer = LabelBinarizer().fit(true_labels)
y_onehot_test = label_binarizer.transform(true_labels)

# ------------------------
# 4. Plotting One-vs-Rest ROC Curves
# ------------------------
fig, ax = plt.subplots(figsize=(10, 8))

# Get the list of class names from your mapping (e.g., ['rock', 'paper', ...])
class_names = list(mapping.keys())

for class_id, class_name in enumerate(class_names):
    # Calculate specific AUC for this class to put in the legend
    fpr, tpr, _ = roc_curve(y_onehot_test[:, class_id], y_score[:, class_id])
    roc_auc = auc(fpr, tpr)
    
    # Plot the curve for this class
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC: {class_name} (AUC = {roc_auc:.2f})",
        ax=ax,
        plot_chance_level=False # We will add a custom one for better styling
    )

# Add a professional "Chance Level" diagonal line
ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='red', label='Random Guessing', alpha=.8)

# Styling
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.set_title("Multi-class One-vs-Rest ROC Curves (Test Set 2)")
ax.legend(loc="lower right")
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[500], line 49
#      45 class_names = list(mapping.keys())
#      47 for class_id, class_name in enumerate(class_names):
#      48     # Calculate specific AUC for this class to put in the legend
# ---> 49     fpr, tpr, _ = roc_curve(y_onehot_test[:, class_id], y_score[:, class_id])
#      50     roc_auc = auc(fpr, tpr)
#      52     # Plot the curve for this class
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %% [markdown]
# ## K-Fold

# %%
# Ensure reproducibility
torch.manual_seed(SEED)

# 1. Initialize storage for metrics
all_train_losses = [] 
all_test_losses  = [] 
fold_train_accs = [] 
fold_test_accs = [] 
fold_precisions = []
fold_recalss = []
fold_f1_scores = []

# Prepare data for StratifiedKFold (requires numpy for indices)
X_np = X.numpy()
y_np = y.numpy()

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)

# ------------------------
# K-Fold Loop
# ------------------------
for fold, (train_idx, test_idx) in enumerate(skf.split(X_np, y_np)):
    print(f"\n{'='*40}")
    print(f"   FOLD {fold + 1} / {N_FOLDS}")
    print(f"{'='*40}")

    # Split and move to device
    X_train_fold, y_train_fold = X[train_idx].to(device), y[train_idx].long().to(device)
    X_test_fold, y_test_fold   = X[test_idx].to(device), y[test_idx].long().to(device)

    # Re-initialize Model, Loss, and Optimizer for a fresh start each fold
    model = RPSModel(input_features=input_features, output_features=classes).to(device)
    loss_fn = nn.CrossEntropyLoss()
    
    # Using Adam for better stability with unscaled sensor features
    optimizer = torch.optim.Adam(params=model.parameters(), lr=0.001)

    train_losses_per_epoch = []
    test_losses_per_epoch = []
    
    for epoch in range(EPOCHS):
        ### Training Phase
        model.train()
        y_logits = model(X_train_fold)
        y_pred = torch.argmax(y_logits, dim=1)
        
        loss = loss_fn(y_logits, y_train_fold)
        train_acc = accuracy_fn(y_true=y_train_fold, y_pred=y_pred)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        ### Validation/Test Phase (for this fold)
        model.eval()
        with torch.inference_mode():
            test_logits = model(X_test_fold)
            test_pred = torch.argmax(test_logits, dim=1)
            test_loss = loss_fn(test_logits, y_test_fold)
            test_acc = accuracy_fn(y_true=y_test_fold, y_pred=test_pred)

        train_losses_per_epoch.append(loss.item())
        test_losses_per_epoch.append(test_loss.item())

        if epoch % 100 == 0 or epoch == EPOCHS - 1:
            print(f"   Epoch: {epoch} | Train Loss: {loss:.5f}, Acc: {train_acc:.2f}% | Test Loss: {test_loss:.5f}, Acc: {test_acc:.2f}%")

    # Store final metrics for this fold
    all_train_losses.append(train_losses_per_epoch)
    all_test_losses.append(test_losses_per_epoch)
    fold_train_accs.append(train_acc)
    fold_test_accs.append(test_acc)

    # Detailed report for the current fold
    report = classification_report(
        y_test_fold.cpu(), 
        test_pred.cpu(), 
        target_names=list(mapping.keys()), 
        output_dict=True, 
        zero_division=0
    )
    
    fold_precisions.append(report['macro avg']['precision'])
    fold_recalss.append(report['macro avg']['recall'])
    fold_f1_scores.append(report['macro avg']['f1-score'])

# ------------------------
# 5. Visualizing Cross-Validation Progress
# ------------------------
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
for i, losses in enumerate(all_train_losses):
    plt.plot(losses, label=f'Fold {i+1}', alpha=0.6)
plt.title('Training Loss - All Folds')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
for i, losses in enumerate(all_test_losses):
    plt.plot(losses, label=f'Fold {i+1}', alpha=0.6)
plt.title('Validation Loss - All Folds')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# ------------------------
# 6. Final Summary Statistics
# ------------------------
print(f"\n{'='*40}")
print(f"   K-FOLD FINAL SUMMARY")
print(f"{'='*40}")
for i, (tr, te) in enumerate(zip(fold_train_accs, fold_test_accs)):
    print(f"   Fold {i+1}: Train {tr:.2f}%  |  Test {te:.2f}%")

print(f"\n   Mean Test Acc : {np.mean(fold_test_accs):.2f}% (+/- {np.std(fold_test_accs):.2f}%)")
print(f"   Mean F1-Score : {np.mean(fold_f1_scores):.3f}")
print(f"   Mean Precision: {np.mean(fold_precisions):.3f}")
print(f"   Mean Recall   : {np.mean(fold_recalss):.3f}")
# Out:
# ========================================
#    FOLD 1 / 5
# ========================================
#    Epoch: 0 | Train Loss: 1.44064, Acc: 23.72% | Test Loss: 6.85483, Acc: 25.00%
#    Epoch: 100 | Train Loss: 0.27002, Acc: 93.66% | Test Loss: 1.02195, Acc: 59.09%
#    Epoch: 199 | Train Loss: 0.09780, Acc: 98.01% | Test Loss: 1.98334, Acc: 32.06%
#
# ========================================
#    FOLD 2 / 5
# ========================================
#    Epoch: 0 | Train Loss: 1.45368, Acc: 26.69% | Test Loss: 5.01099, Acc: 25.00%
#    Epoch: 100 | Train Loss: 0.29612, Acc: 92.75% | Test Loss: 1.34991, Acc: 31.77%
#    Epoch: 199 | Train Loss: 0.09955, Acc: 97.91% | Test Loss: 1.09275, Acc: 60.97%
#
# ========================================
#    FOLD 3 / 5
# ========================================
#    Epoch: 0 | Train Loss: 1.45781, Acc: 25.32% | Test Loss: 3.21180, Acc: 33.12%
#    Epoch: 100 | Train Loss: 0.35483, Acc: 90.53% | Test Loss: 1.00826, Acc: 58.92%
#    Epoch: 199 | Train Loss: 0.09975, Acc: 97.91% | Test Loss: 0.58042, Acc: 81.71%
#
# ========================================
#    FOLD 4 / 5
# ========================================
#    Epoch: 0 | Train Loss: 1.46186, Acc: 26.27% | Test Loss: 4.55219, Acc: 25.00%
#    Epoch: 100 | Train Loss: 0.31140, Acc: 92.54% | Test Loss: 1.01487, Acc: 70.90%
#    Epoch: 199 | Train Loss: 0.10124, Acc: 97.95% | Test Loss: 0.60428, Acc: 76.71%
#
# ========================================
#    FOLD 5 / 5
# ========================================
#    Epoch: 0 | Train Loss: 1.42796, Acc: 26.12% | Test Loss: 2.28874, Acc: 25.40%
#    Epoch: 100 | Train Loss: 0.27756, Acc: 93.28% | Test Loss: 3.33192, Acc: 25.08%
#    Epoch: 199 | Train Loss: 0.09923, Acc: 97.95% | Test Loss: 1.01393, Acc: 71.53%
# ========================================
#    K-FOLD FINAL SUMMARY
# ========================================
#    Fold 1: Train 98.01%  |  Test 32.06%
#    Fold 2: Train 97.91%  |  Test 60.97%
#    Fold 3: Train 97.91%  |  Test 81.71%
#    Fold 4: Train 97.95%  |  Test 76.71%
#    Fold 5: Train 97.95%  |  Test 71.53%
#
#    Mean Test Acc : 64.60% (+/- 17.66%)
#    Mean F1-Score : 0.593
#    Mean Precision: 0.838
#    Mean Recall   : 0.646

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*50)
print("           FINAL PERFORMANCE SUMMARY")
print("="*50)

# 1. Accuracy Comparison
acc_raw = accuracy_score(true_numeric, max_classes)
acc_thresh = accuracy_score(true_numeric, pred_classes_thresh)

print(f"Overall Accuracy (Raw):         {acc_raw:.4f}")
print(f"Overall Accuracy (Thresholded): {acc_thresh:.4f}")
print(f"F1-Score (Weighted):            {f1_score(true_numeric, max_classes, average='weighted'):.4f}")

# 2. Cross-Validation Results
print(f"\nK-Fold Mean Test Accuracy:      {np.mean(fold_test_accs):.2f}%")
print(f"K-Fold Std Deviation:           {np.std(fold_test_accs):.2f}%")

# 3. Average Confidence (Clean Logic)
print("\n--- Average Confidence per Predicted Class ---")
for class_name, class_idx in mapping.items():
    # Use the thresholded predictions to see how confident the model was for each group
    class_mask = (pred_classes_thresh == class_idx)
    confidences_for_class = max_probs[class_mask]

    if len(confidences_for_class) > 0:
        avg_confidence = np.mean(confidences_for_class)
        print(f"{class_name.capitalize():<10}: {avg_confidence:.4f} (N={len(confidences_for_class)})")
    else:
        print(f"{class_name.capitalize():<10}: No predictions for this class.")
# Out:
# ==================================================
#            FINAL PERFORMANCE SUMMARY
# ==================================================
# Overall Accuracy (Raw):         0.7792
# Overall Accuracy (Thresholded): 0.7810
# F1-Score (Weighted):            0.7751
#
# K-Fold Mean Test Accuracy:      64.60%
# K-Fold Std Deviation:           17.66%
#
# --- Average Confidence per Predicted Class ---
# None      : 0.9157 (N=1568)
# Paper     : 0.9714 (N=428)
# Rock      : 0.9682 (N=287)
# Scissors  : 0.9821 (N=502)

# %% [markdown]
# # Which features are the most important?

# %%
# 1. Prepare Data and Baseline
y_new_tensor = torch.tensor(true_numeric2).long().to(device)
model_4.eval()

with torch.inference_mode():
    baseline_logits = model_4(X_new) 
    baseline_pred = torch.argmax(baseline_logits, dim=1)
    baseline_acc = accuracy_fn(y_true=y_new_tensor, y_pred=baseline_pred)

print(f"Baseline Accuracy on Test Set 2: {baseline_acc:.2f}%")

# 2. Extract Feature Names from your training template
# Using X_train.columns ensures we match the specific indices used by the model
feature_names = list(X_train.columns)
num_features = len(feature_names)

# 3. Calculate Importance per Feature
importances = []
for i in range(num_features):
    X_permuted = X_new.clone()
    X_permuted[:, i] = X_new[torch.randperm(X_new.shape[0]), i] 

    with torch.inference_mode():
        perm_logits = model_4(X_permuted)
        perm_pred = torch.argmax(perm_logits, dim=1)
        perm_acc = accuracy_fn(y_true=y_new_tensor, y_pred=perm_pred)
    
    importances.append(baseline_acc - perm_acc)

# 4. Define Feature Groups (Mappings stay the same, but colors apply to names)
group_colors = {
    'Accel': '#e74c3c', # Red
    'Gyro':  '#2ecc71', # Green
    'Mag':   '#3498db'  # Blue
}

feature_colors = []
for i in range(num_features):
    assigned_color = '#95a5a6' # Default Gray
    name_lower = feature_names[i].lower()
    
    if 'acc' in name_lower:
        assigned_color = group_colors['Accel']
    elif 'gyr' in name_lower:
        assigned_color = group_colors['Gyro']
    elif 'mag' in name_lower:
        assigned_color = group_colors['Mag']
    
    feature_colors.append(assigned_color)

# 5. Plotting with Feature Names
plt.figure(figsize=(16, 8))
plt.bar(feature_names, importances, color=feature_colors, edgecolor='black', alpha=0.8)

plt.xlabel("Sensor Feature Name", fontsize=12)
plt.ylabel("Drop in Accuracy (%)", fontsize=12)
plt.title("Permutation Feature Importance (Named Features)", fontsize=14)
plt.axhline(0, color='black', lw=1)
plt.grid(axis='y', linestyle='--', alpha=0.3)

# Rotate labels so they don't overlap
plt.xticks(rotation=90, fontsize=9)

# Custom Legend
handles = [plt.Rectangle((0,0),1,1, color=group_colors[g]) for g in group_colors]
plt.legend(handles, group_colors.keys(), title="Sensor Type", loc='upper right')

plt.tight_layout()
plt.show()

# 6. Print Top 5 Critical Features by Name
sorted_idx = np.argsort(importances)[::-1]
print("\n--- Top 5 Most Critical Features ---")
for i in range(5):
    idx = sorted_idx[i]
    print(f"{i+1}. {feature_names[idx]:<20} | Importance Score: {importances[idx]:.4f}")
# Out:
# Baseline Accuracy on Test Set 2: 77.92%
# --- Top 5 Most Critical Features ---
# 1. BNO2_UnitAccX        | Importance Score: 6.7504
# 2. BNO2_MagY            | Importance Score: 2.8007
# 3. BNO0_UnitAccX        | Importance Score: 2.5494
# 4. BNO2_UnitAccY        | Importance Score: 1.2926
# 5. BNO2_MagX            | Importance Score: 1.1131

# %%
# 1. Prepare the input for gradients using X_new (Test Set 2)
X_grad_input = X_new.clone().detach().requires_grad_(True)

# 2. Forward pass (Manual eval, no inference_mode because we need the gradient graph)
model_4.eval()
output = model_4(X_grad_input)

# 3. Backward pass on the sum of max logits
# This calculates how much the output 'wiggles' relative to the input features
output.max(dim=1).values.sum().backward()

# 4. Extract Importance (Mean Absolute Gradient)
importances = X_grad_input.grad.abs().mean(dim=0).cpu().detach().numpy()

# 5. Get Feature Names from your original DataFrame
feature_names = list(X_train.columns)
num_features = len(feature_names)

# 6. Define Colors based on feature name keywords
group_colors = {
    'Accel': '#e74c3c', # Red
    'Gyro':  '#2ecc71', # Green
    'Mag':   '#3498db'  # Blue
}

feature_colors = []
for i in range(num_features):
    assigned_color = '#95a5a6' # Default gray
    name_lower = feature_names[i].lower()
    
    if 'acc' in name_lower:
        assigned_color = group_colors['Accel']
    elif 'gyr' in name_lower:
        assigned_color = group_colors['Gyro']
    elif 'mag' in name_lower:
        assigned_color = group_colors['Mag']
        
    feature_colors.append(assigned_color)

# 7. Plotting with Feature Names
plt.figure(figsize=(16, 7))
plt.bar(feature_names, importances, color=feature_colors, edgecolor='black', alpha=0.8)

plt.title("Gradient-based Feature Importance (Named Saliency)", fontsize=14)
plt.xlabel("Sensor Feature Name", fontsize=12)
plt.ylabel("Mean Absolute Gradient (Sensitivity)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.3)

# Rotate labels for readability
plt.xticks(rotation=90, fontsize=9)

# Create legend
handles = [plt.Rectangle((0,0),1,1, color=group_colors[g]) for g in group_colors]
plt.legend(handles, group_colors.keys(), title="Feature Types", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print Top 5 Saliency Features
sorted_idx = np.argsort(importances)[::-1]
print("\n--- Top 5 Features the Model is 'Looking At' (Saliency) ---")
for i in range(5):
    idx = sorted_idx[i]
    print(f"{i+1}. {feature_names[idx]:<20} | Gradient Sensitivity: {importances[idx]:.6f}")
# Out:
# --- Top 5 Features the Model is 'Looking At' (Saliency) ---
# 1. BNO0_UnitAccX        | Gradient Sensitivity: 1.306201
# 2. BNO0_UnitAccY        | Gradient Sensitivity: 1.180225
# 3. BNO0_MagY            | Gradient Sensitivity: 1.039051
# 4. BNO2_UnitAccZ        | Gradient Sensitivity: 1.032197
# 5. BNO1_UnitAccZ        | Gradient Sensitivity: 1.013906

# %%
mapping2
# Out:
# {'none': 0, 'paper': 1, 'rock': 2, 'scissors': 3}

# %% [markdown]
# # Live Testing

# %%
import asyncio
import websockets
import torch
import numpy as np

# 1. Configuration
PICO_URI = "ws://192.168.4.1:81"
CONFIDENCE_THRESHOLD = 0.82 
GESTURE_MAP = {0: "None", 1: "Paper", 2: "Rock", 3: "Scissors"}

async def live_glove_inference():
    # Detect expected features from the actual model
    # expected_features = model_4.state_dict()['fc1.weight'].shape[1]
    # print(f"Model verified: Expecting {expected_features} features per row.")

    while True:
        try:
            # Added ping_interval=None to stop the client from timing out the Pico
            async with websockets.connect(PICO_URI, ping_interval=None) as websocket:
                print(f"\n--- Connected to Glove at {PICO_URI} ---")
                
                # The first message is the header; we grab it once and move on
                header = await websocket.recv()
                print(f"Header ignored. Streaming data...")

                model_4.eval()
                
                while True:
                    # Receive raw CSV string
                    raw_message = await websocket.recv()
                    
                    try:
                        # Fast conversion
                        data_points = [float(x) for x in raw_message.split(',')]
                        
                        # Guard rail for malformed strings
                        # if len(data_points) != expected_features:
                        #     continue

                        # Move to device (CPU is usually faster for single-row inference)
                        input_tensor = torch.tensor(data_points, dtype=torch.float32).unsqueeze(0).to(device)
                        
                        with torch.inference_mode():
                            logits = model_4(input_tensor)
                            probs = torch.softmax(logits, dim=1)
                            max_conf, pred_idx = torch.max(probs, dim=1)
                        
                        confidence = max_conf.item()
                        
                        if confidence > CONFIDENCE_THRESHOLD:
                            gesture = GESTURE_MAP[pred_idx.item()]
                            # \r allows the line to overwrite itself for a clean dashboard look
                            print(f"Detected: {gesture:10} | Confidence: {confidence:.2f}", end="\r")
                        else:
                            print(f"Detected: {'None':10} | Confidence: {confidence:.2f}", end="\r")

                    except (ValueError, IndexError):
                        # Skips any stray text or empty lines
                        continue

        except (websockets.ConnectionClosed, OSError) as e:
            print(f"\n[Status] Connection dropped ({e}). Reconnecting...")
            await asyncio.sleep(1)

# Run the live loop
# await live_glove_inference()

# %%
import asyncio
import websocket

# These are the indices of Accel and Mag data, skipping all 'Gyr' columns
# Total expected features: 36
KEEP_INDICES = [
    # BNO0
    0, 1, 2, 3, 7, 8, 9,
    # BNO1
    10, 11, 12, 13, 17, 18, 19,
    # BNO2
    20, 21, 22, 23, 27, 28, 29,
    # BNO3
    30, 31, 32, 33, 37, 38, 39,
    # MPU0
    40, 41, 42, 43, 
    # MPU1
    47, 48, 49, 50
]

def run_live_inference_hardcoded():
    # Model check
    # expected_features = model_4.state_dict()['fc1.weight'].shape[1]
    # if len(KEEP_INDICES) != expected_features:
    #     print(f"Error: Mask size ({len(KEEP_INDICES)}) != Model inputs ({expected_features})")
    #     return

    try:
        ws = websocket.create_connection(PICO_URI, timeout=5)
        print(f"--- Connected to Glove at {PICO_URI} ---")
        ws.recv() # Skip Header
        model_4.eval()

        while True:
            raw_message = ws.recv()
            if not raw_message: continue

            try:
                # 1. Parse all 54 incoming floats
                full_data = [float(x) for x in raw_message.split(',')]
                
                # 2. Extract only the Accel/Mag indices
                filtered_data = [full_data[i] for i in KEEP_INDICES]
                
                # 3. Predict
                input_tensor = torch.tensor(filtered_data, dtype=torch.float32).unsqueeze(0).to(device)
                
                with torch.inference_mode():
                    logits = model_4(input_tensor)
                    probs = torch.softmax(logits, dim=1)
                    max_conf, pred_idx = torch.max(probs, dim=1)
                
                confidence = max_conf.item()
                
                # 4. Display Result
                if confidence > CONFIDENCE_THRESHOLD:
                    gesture = GESTURE_MAP[pred_idx.item()]
                    print(f"Detected: {gesture:10} | Confidence: {confidence:.2f}", end="\r")
                else:
                    print(f"Detected: {'None':10} | Confidence: {confidence:.2f}", end="\r")

            except (ValueError, IndexError):
                continue

    except KeyboardInterrupt:
        print("\nStopping...")
    except Exception as e:
        print(f"\nConnection Error: {e}")
    finally:
        if 'ws' in locals(): ws.close()

run_live_inference_hardcoded()
# Out:
# --- Connected to Glove at ws://192.168.4.1:81 ---
# Detected: None       | Confidence: 0.96

# %%
import torch
import websocket
import numpy as np
from collections import deque
import time

# --- Configuration (Ensure these match your training) ---
WINDOW_SIZE = 5  # Match the window size you used in your CSV script
PICO_URI = "ws://192.168.4.1:81"
CONFIDENCE_THRESHOLD = 0.8
GESTURE_MAP = {0: "None", 1: "Paper", 2: "Rock", 3: "Scissors"}

# Accel and Mag data indices (36 total)
KEEP_INDICES = [
    0, 1, 2, 3, 7, 8, 9, 10, 11, 12, 13, 17, 18, 19,
    20, 21, 22, 23, 27, 28, 29, 30, 31, 32, 33, 37, 
    38, 39, 40, 41, 42, 43, 47, 48, 49, 50
]

def run_live_inference_windowed(model):
    # 1. Initialize sliding window buffer
    # Each entry will be the 36 filtered features
    window_buffer = deque(maxlen=WINDOW_SIZE)
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    try:
        ws = websocket.create_connection(PICO_URI, timeout=5)
        print(f"--- Connected to Glove at {PICO_URI} ---")
        print(f"--- Using Window Size: {WINDOW_SIZE} ---")
        ws.recv() # Skip Header

        while True:
            raw_message = ws.recv()
            if not raw_message: continue

            try:
                # 2. Parse and Filter
                full_data = [float(x) for x in raw_message.split(',')]
                filtered_sample = [full_data[i] for i in KEEP_INDICES]
                
                # 3. Add to sliding window
                window_buffer.append(filtered_sample)

                # Wait until buffer is full before predicting
                if len(window_buffer) < WINDOW_SIZE:
                    continue

                # 4. Calculate Stats (Mean & Variance)
                # Convert buffer to (WINDOW_SIZE, 36) array
                data_window = np.array(window_buffer)
                means = np.mean(data_window, axis=0)
                variances = np.var(data_window, axis=0)

                # 5. Prepare Input Tensor
                # Option A: If your model was trained on [Means, Variances] (72 features)
                combined_input = np.concatenate([means, variances])
                
                # Option B: If your model only uses Means (36 features)
                # combined_input = means 

                input_tensor = torch.tensor(combined_input, dtype=torch.float32).unsqueeze(0).to(device)
                
                # 6. Inference
                with torch.inference_mode():
                    logits = model(input_tensor)
                    probs = torch.softmax(logits, dim=1)
                    max_conf, pred_idx = torch.max(probs, dim=1)
                
                confidence = max_conf.item()
                
                # 7. Display
                if confidence > CONFIDENCE_THRESHOLD:
                    gesture = GESTURE_MAP[pred_idx.item()]
                    print(f"Detected: {gesture:10} | Conf: {confidence:.2f}", end="\r")
                else:
                    print(f"Detected: {'None':10} | Conf: {confidence:.2f}", end="\r")

            except (ValueError, IndexError):
                continue

    except KeyboardInterrupt:
        print("\nStopping Live Inference...")
    except Exception as e:
        print(f"\nError: {e}")
    finally:
        if 'ws' in locals(): ws.close()

# To run:
run_live_inference_windowed(model_4)
# Out:
# Error: timed out
